# %%
import pandas as pd

wd = '/Users/ewenwang/Documents/practice_data/conversion_rate/'
file = 'snow_data.txt'
file_UISC = 'snow_data_UISC.txt'
feature_conversion = 'feature_conversion.txt'
pagerank='pagerank.txt'

# %%
data = pd.read_csv(wd+file_UISC, sep=' ')
data = data.merge(pd.read_csv(wd+feature_conversion, sep=' '), on='instance_id', how='left').merge(pd.read_csv(wd+pagerank, sep=' '), on='instance_id', how='left')

# %%
for i in data.columns:
    print(i)
# Out:
# context_id
# context_page_id
# context_timestamp
# instance_id
# is_trade
# item_brand_id
# item_category_list
# item_city_id
# item_collected_level
# item_id
# item_price_level
# item_property_list
# item_pv_level
# item_sales_level
# predict_category_property
# shop_id
# shop_review_num_level
# shop_review_positive_rate
# shop_score_delivery
# shop_score_description
# shop_score_service
# shop_star_level
# user_age_level
# user_gender_id
# user_id
# user_occupation_id
# user_star_level
# len_item_category
# len_item_property
# item_category_list1
# item_category_list2
# item_property_list0
# item_property_list1
# item_property_list2
# item_property_list3
# item_property_list4
# item_property_list5
# item_property_list6
# item_property_list7
# item_property_list8
# item_property_list9
# gender0
# age0
# occupation0
# star0
# realtime
# day
# hour
# len_predict_category_property
# predict_category_property0
# predict_category_property1
# predict_category_property2
# predict_category_property3
# predict_category_property4
# context_page0
# shop_score_delivery0
# hour_map
# user_gender_id_user_id_cnt
# user_gender_id_user_id_prob
# user_age_level_user_id_cnt
# user_age_level_user_id_prob
# user_occupation_id_user_id_cnt
# user_occupation_id_user_id_prob
# user_star_level_user_id_cnt
# user_star_level_user_id_prob
# user_age_level_user_gender_id_cnt
# user_age_level_user_gender_id_prob
# user_occupation_id_user_gender_id_cnt
# user_occupation_id_user_gender_id_prob
# user_star_level_user_gender_id_cnt
# user_star_level_user_gender_id_prob
# user_occupation_id_user_age_level_cnt
# user_occupation_id_user_age_level_prob
# user_star_level_user_age_level_cnt
# user_star_level_user_age_level_prob
# user_star_level_user_occupation_id_cnt
# user_star_level_user_occupation_id_prob
# item_brand_id_item_id_cnt
# item_brand_id_item_id_prob
# item_city_id_item_id_cnt
# item_city_id_item_id_prob
# item_price_level_item_id_cnt
# item_price_level_item_id_prob
# item_sales_level_item_id_cnt
# item_sales_level_item_id_prob
# item_collected_level_item_id_cnt
# item_collected_level_item_id_prob
# item_pv_level_item_id_cnt
# item_pv_level_item_id_prob
# item_city_id_item_brand_id_cnt
# item_city_id_item_brand_id_prob
# item_price_level_item_brand_id_cnt
# item_price_level_item_brand_id_prob
# item_sales_level_item_brand_id_cnt
# item_sales_level_item_brand_id_prob
# item_collected_level_item_brand_id_cnt
# item_collected_level_item_brand_id_prob
# item_pv_level_item_brand_id_cnt
# item_pv_level_item_brand_id_prob
# item_price_level_item_city_id_cnt
# item_price_level_item_city_id_prob
# item_sales_level_item_city_id_cnt
# item_sales_level_item_city_id_prob
# item_collected_level_item_city_id_cnt
# item_collected_level_item_city_id_prob
# item_pv_level_item_city_id_cnt
# item_pv_level_item_city_id_prob
# item_sales_level_item_price_level_cnt
# item_sales_level_item_price_level_prob
# item_collected_level_item_price_level_cnt
# item_collected_level_item_price_level_prob
# item_pv_level_item_price_level_cnt
# item_pv_level_item_price_level_prob
# item_collected_level_item_sales_level_cnt
# item_collected_level_item_sales_level_prob
# item_pv_level_item_sales_level_cnt
# item_pv_level_item_sales_level_prob
# item_pv_level_item_collected_level_cnt
# item_pv_level_item_collected_level_prob
# shop_review_num_level_shop_id_cnt
# shop_review_num_level_shop_id_prob
# shop_star_level_shop_id_cnt
# shop_star_level_shop_id_prob
# shop_star_level_shop_review_num_level_cnt
# shop_star_level_shop_review_num_level_prob
# hour_map_context_id_cnt
# hour_map_context_id_prob
# context_page0_context_id_cnt
# context_page0_context_id_prob
# context_page0_hour_map_cnt
# context_page0_hour_map_prob
# item_id_user_id_cnt
# item_id_user_id_prob
# item_brand_id_user_id_cnt
# item_brand_id_user_id_prob
# item_city_id_user_id_cnt
# item_city_id_user_id_prob
# item_price_level_user_id_cnt
# item_price_level_user_id_prob
# item_sales_level_user_id_cnt
# item_sales_level_user_id_prob
# item_collected_level_user_id_cnt
# item_collected_level_user_id_prob
# item_pv_level_user_id_cnt
# item_pv_level_user_id_prob
# item_id_user_gender_id_cnt
# item_id_user_gender_id_prob
# item_brand_id_user_gender_id_cnt
# item_brand_id_user_gender_id_prob
# item_city_id_user_gender_id_cnt
# item_city_id_user_gender_id_prob
# item_price_level_user_gender_id_cnt
# item_price_level_user_gender_id_prob
# item_sales_level_user_gender_id_cnt
# item_sales_level_user_gender_id_prob
# item_collected_level_user_gender_id_cnt
# item_collected_level_user_gender_id_prob
# item_pv_level_user_gender_id_cnt
# item_pv_level_user_gender_id_prob
# item_id_user_age_level_cnt
# item_id_user_age_level_prob
# item_brand_id_user_age_level_cnt
# item_brand_id_user_age_level_prob
# item_city_id_user_age_level_cnt
# item_city_id_user_age_level_prob
# item_price_level_user_age_level_cnt
# item_price_level_user_age_level_prob
# item_sales_level_user_age_level_cnt
# item_sales_level_user_age_level_prob
# item_collected_level_user_age_level_cnt
# item_collected_level_user_age_level_prob
# item_pv_level_user_age_level_cnt
# item_pv_level_user_age_level_prob
# item_id_user_occupation_id_cnt
# item_id_user_occupation_id_prob
# item_brand_id_user_occupation_id_cnt
# item_brand_id_user_occupation_id_prob
# item_city_id_user_occupation_id_cnt
# item_city_id_user_occupation_id_prob
# item_price_level_user_occupation_id_cnt
# item_price_level_user_occupation_id_prob
# item_sales_level_user_occupation_id_cnt
# item_sales_level_user_occupation_id_prob
# item_collected_level_user_occupation_id_cnt
# item_collected_level_user_occupation_id_prob
# item_pv_level_user_occupation_id_cnt
# item_pv_level_user_occupation_id_prob
# shop_id_user_id_cnt
# shop_id_user_id_prob
# shop_review_num_level_user_id_cnt
# shop_review_num_level_user_id_prob
# shop_star_level_user_id_cnt
# shop_star_level_user_id_prob
# shop_id_user_gender_id_cnt
# shop_id_user_gender_id_prob
# shop_review_num_level_user_gender_id_cnt
# shop_review_num_level_user_gender_id_prob
# shop_star_level_user_gender_id_cnt
# shop_star_level_user_gender_id_prob
# shop_id_user_age_level_cnt
# shop_id_user_age_level_prob
# shop_review_num_level_user_age_level_cnt
# shop_review_num_level_user_age_level_prob
# shop_star_level_user_age_level_cnt
# shop_star_level_user_age_level_prob
# shop_id_user_occupation_id_cnt
# shop_id_user_occupation_id_prob
# shop_review_num_level_user_occupation_id_cnt
# shop_review_num_level_user_occupation_id_prob
# shop_star_level_user_occupation_id_cnt
# shop_star_level_user_occupation_id_prob
# context_id_user_id_cnt
# context_id_user_id_prob
# hour_map_user_id_cnt
# hour_map_user_id_prob
# context_page0_user_id_cnt
# context_page0_user_id_prob
# context_id_user_gender_id_cnt
# context_id_user_gender_id_prob
# hour_map_user_gender_id_cnt
# hour_map_user_gender_id_prob
# context_page0_user_gender_id_cnt
# context_page0_user_gender_id_prob
# context_id_user_age_level_cnt
# context_id_user_age_level_prob
# hour_map_user_age_level_cnt
# hour_map_user_age_level_prob
# context_page0_user_age_level_cnt
# context_page0_user_age_level_prob
# context_id_user_occupation_id_cnt
# context_id_user_occupation_id_prob
# hour_map_user_occupation_id_cnt
# hour_map_user_occupation_id_prob
# context_page0_user_occupation_id_cnt
# context_page0_user_occupation_id_prob
# shop_id_item_id_cnt
# shop_id_item_id_prob
# shop_review_num_level_item_id_cnt
# shop_review_num_level_item_id_prob
# shop_star_level_item_id_cnt
# shop_star_level_item_id_prob
# shop_id_item_brand_id_cnt
# shop_id_item_brand_id_prob
# shop_review_num_level_item_brand_id_cnt
# shop_review_num_level_item_brand_id_prob
# shop_star_level_item_brand_id_cnt
# shop_star_level_item_brand_id_prob
# shop_id_item_city_id_cnt
# shop_id_item_city_id_prob
# shop_review_num_level_item_city_id_cnt
# shop_review_num_level_item_city_id_prob
# shop_star_level_item_city_id_cnt
# shop_star_level_item_city_id_prob
# shop_id_item_price_level_cnt
# shop_id_item_price_level_prob
# shop_review_num_level_item_price_level_cnt
# shop_review_num_level_item_price_level_prob
# shop_star_level_item_price_level_cnt
# shop_star_level_item_price_level_prob
# shop_id_item_sales_level_cnt
# shop_id_item_sales_level_prob
# shop_review_num_level_item_sales_level_cnt
# shop_review_num_level_item_sales_level_prob
# shop_star_level_item_sales_level_cnt
# shop_star_level_item_sales_level_prob
# shop_id_item_collected_level_cnt
# shop_id_item_collected_level_prob
# shop_review_num_level_item_collected_level_cnt
# shop_review_num_level_item_collected_level_prob
# shop_star_level_item_collected_level_cnt
# shop_star_level_item_collected_level_prob
# context_id_item_id_cnt
# context_id_item_id_prob
# hour_map_item_id_cnt
# hour_map_item_id_prob
# context_page0_item_id_cnt
# context_page0_item_id_prob
# context_id_item_brand_id_cnt
# context_id_item_brand_id_prob
# hour_map_item_brand_id_cnt
# hour_map_item_brand_id_prob
# context_page0_item_brand_id_cnt
# context_page0_item_brand_id_prob
# context_id_item_city_id_cnt
# context_id_item_city_id_prob
# hour_map_item_city_id_cnt
# hour_map_item_city_id_prob
# context_page0_item_city_id_cnt
# context_page0_item_city_id_prob
# context_id_item_price_level_cnt
# context_id_item_price_level_prob
# hour_map_item_price_level_cnt
# hour_map_item_price_level_prob
# context_page0_item_price_level_cnt
# context_page0_item_price_level_prob
# context_id_item_sales_level_cnt
# context_id_item_sales_level_prob
# hour_map_item_sales_level_cnt
# hour_map_item_sales_level_prob
# context_page0_item_sales_level_cnt
# context_page0_item_sales_level_prob
# context_id_item_collected_level_cnt
# context_id_item_collected_level_prob
# hour_map_item_collected_level_cnt
# hour_map_item_collected_level_prob
# context_page0_item_collected_level_cnt
# context_page0_item_collected_level_prob
# context_id_shop_id_cnt
# context_id_shop_id_prob
# hour_map_shop_id_cnt
# hour_map_shop_id_prob
# context_page0_shop_id_cnt
# context_page0_shop_id_prob
# context_id_shop_review_num_level_cnt
# context_id_shop_review_num_level_prob
# hour_map_shop_review_num_level_cnt
# hour_map_shop_review_num_level_prob
# context_page0_shop_review_num_level_cnt
# context_page0_shop_review_num_level_prob
# normal_shop
# user_cnt_1_x
# item_cnt_1_x
# shop_cnt_1_x
# user_cnt_2
# item_cnt_2
# shop_cnt_2
# user_cnt_1_y
# item_cnt_1_y
# shop_cnt_1_y
# sale_price
# sale_collect
# price_collect
# gender_age
# gender_occ
# gender_star
# user_id_count
# user_id_trade_count
# user_id_cvr
# item_id_count
# item_id_trade_count
# item_id_cvr
# shop_id_count
# shop_id_trade_count
# shop_id_cvr
# context_id_count
# context_id_trade_count
# context_id_cvr
# Unnamed: 0
# user_pagerank
# item_pagerank

# %%
import gossipcat as gc

# %%
drop_list = ['item_category_list', 'item_property_list', 'predict_category_property', 'realtime', 'context_timestamp', 'Unnamed: 0']
features = [x for x in data.columns if x not in drop_list]

# %%
Feature = gc.Feature(data, target, features)

int_f, float_f, obj_f = Feature.classify()
# Out:
# classifying...
# int features count: 185
# float features count: 159
# object features count: 0

# %%
cap_data = data[features]
cap_data.to_csv(wd+'cap_data.txt', sep=' ', index=False)

# %%
data = pd.read_csv(wd+file, sep=' ')
data = data.merge(pd.read_csv(wd+pagerank, sep=' '), on='instance_id', how='left')

# %% [markdown]
# ## results 27

# %%
cloud_data = data[features]
cloud_data.to_csv(wd+'cloud_data.txt', sep=' ', index=False)

# %%
cloud_data.head()
# Out:
#             context_id  context_page_id          instance_id  is_trade  \
# 0   282924576738839389             4006   108641074714126964       0.0
# 1  4007979028023783431             4001  5754713551599725161       0.0
# 2  4884875192608989870             4001   842679481291040981       0.0
# 3   840119421106178602             4016   937088850059189027       0.0
# 4  1736769971710354684             4001  7975697065017708072       0.0
#
#    item_brand_id  item_city_id  item_collected_level  item_id  \
# 0            453            50                     4     3804
# 1            453            50                     4     3804
# 2            453            50                     4     3804
# 3            453            50                     4     3804
# 4            453            50                     4     3804
#
#    item_price_level  item_pv_level      ...        \
# 0                 3             14      ...
# 1                 3             14      ...
# 2                 3             14      ...
# 3                 3             14      ...
# 4                 3             14      ...
#
#    item_price_level_shop_review_num_level_cnt  \
# 0                                          24
# 1                                          24
# 2                                          24
# 3                                          24
# 4                                          24
#
#    item_price_level_shop_review_num_level_prob  \
# 0                                     0.088561
# 1                                     0.088561
# 2                                     0.088561
# 3                                     0.088561
# 4                                     0.088561
#
#    item_sales_level_shop_review_num_level_cnt  \
# 0                                          64
# 1                                          64
# 2                                          64
# 3                                          64
# 4                                          64
#
#    item_sales_level_shop_review_num_level_prob  \
# 0                                     0.236162
# 1                                     0.236162
# 2                                     0.236162
# 3                                     0.236162
# 4                                     0.236162
#
#    item_collected_level_shop_review_num_level_cnt  \
# 0                                              46
# 1                                              46
# 2                                              46
# 3                                              46
# 4                                              46
#
#    item_collected_level_shop_review_num_level_prob  \
# 0                                         0.169742
# 1                                         0.169742
# 2                                         0.169742
# 3                                         0.169742
# 4                                         0.169742
#
#    item_pv_level_shop_review_num_level_cnt  \
# 0                                       21
# 1                                       21
# 2                                       21
# 3                                       21
# 4                                       21
#
#    item_pv_level_shop_review_num_level_prob  user_pagerank  item_pagerank
# 0                                  0.077491       0.000010        0.00002
# 1                                  0.077491       0.000010        0.00002
# 2                                  0.077491       0.000003        0.00002
# 3                                  0.077491       0.000002        0.00002
# 4                                  0.077491       0.000003        0.00002
#
# [5 rows x 243 columns]

# %%
y = cloud_data.is_trade
X = cloud_data.drop(columns='is_trade')

# %%
X.shape
# Out:
# (496449, 242)

# %%
from sklearn.preprocessing import Imputer
import numpy as np

imp = Imputer(missing_values='NaN', strategy='mean', axis=0)

X_imputed = imp.fit_transform(np.asarray(X))

# %%
X_imputed = pd.DataFrame(X_imputed, columns=X.columns)

# %%
X_imputed.head()
# Out:
#      context_id  context_page_id   instance_id  item_brand_id  item_city_id  \
# 0  2.829246e+17           4006.0  1.086411e+17          453.0          50.0
# 1  4.007979e+18           4001.0  5.754714e+18          453.0          50.0
# 2  4.884875e+18           4001.0  8.426795e+17          453.0          50.0
# 3  8.401194e+17           4016.0  9.370889e+17          453.0          50.0
# 4  1.736770e+18           4001.0  7.975697e+18          453.0          50.0
#
#    item_collected_level  item_id  item_price_level  item_pv_level  \
# 0                   4.0   3804.0               3.0           14.0
# 1                   4.0   3804.0               3.0           14.0
# 2                   4.0   3804.0               3.0           14.0
# 3                   4.0   3804.0               3.0           14.0
# 4                   4.0   3804.0               3.0           14.0
#
#    item_sales_level      ...        \
# 0               3.0      ...
# 1               3.0      ...
# 2               3.0      ...
# 3               3.0      ...
# 4               3.0      ...
#
#    item_price_level_shop_review_num_level_cnt  \
# 0                                        24.0
# 1                                        24.0
# 2                                        24.0
# 3                                        24.0
# 4                                        24.0
#
#    item_price_level_shop_review_num_level_prob  \
# 0                                     0.088561
# 1                                     0.088561
# 2                                     0.088561
# 3                                     0.088561
# 4                                     0.088561
#
#    item_sales_level_shop_review_num_level_cnt  \
# 0                                        64.0
# 1                                        64.0
# 2                                        64.0
# 3                                        64.0
# 4                                        64.0
#
#    item_sales_level_shop_review_num_level_prob  \
# 0                                     0.236162
# 1                                     0.236162
# 2                                     0.236162
# 3                                     0.236162
# 4                                     0.236162
#
#    item_collected_level_shop_review_num_level_cnt  \
# 0                                            46.0
# 1                                            46.0
# 2                                            46.0
# 3                                            46.0
# 4                                            46.0
#
#    item_collected_level_shop_review_num_level_prob  \
# 0                                         0.169742
# 1                                         0.169742
# 2                                         0.169742
# 3                                         0.169742
# 4                                         0.169742
#
#    item_pv_level_shop_review_num_level_cnt  \
# 0                                     21.0
# 1                                     21.0
# 2                                     21.0
# 3                                     21.0
# 4                                     21.0
#
#    item_pv_level_shop_review_num_level_prob  user_pagerank  item_pagerank
# 0                                  0.077491       0.000010        0.00002
# 1                                  0.077491       0.000010        0.00002
# 2                                  0.077491       0.000003        0.00002
# 3                                  0.077491       0.000002        0.00002
# 4                                  0.077491       0.000003        0.00002
#
# [5 rows x 242 columns]

# %%
import pandas as pd 
import lightgbm as lgb
from sklearn.metrics import log_loss
from gossipcat import SimulatedAnneal
import warnings

warnings.filterwarnings('ignore')

wd = '/Users/ewenwang/Documents/practice_data/conversion_rate/'
test_file = 'round1_ijcai_18_test_a_20180301.txt'

file = 'snow_data.txt'
file_slider3 = 'snow_data_slider3.txt'
file_UISC = 'snow_data_UISC.txt'
file_cap = 'cap_data.txt'

feature_cvr = 'feature_cvr.txt'
feature_conversion = 'feature_conversion.txt'

output_file = 'result.txt'

params = {'boosting_type': 'gbdt',
          'max_depth' : 2,
          'objective': 'binary', 
          'num_leaves': 4, 
          'learning_rate': 0.01, 
          'subsample': 0.6, 
          'colsample_bytree': 0.8, 
          'metric' : 'binary_logloss'}

target = 'is_trade'
drop_list = ['is_trade']

# %%
gridParams = {
    'max_depth': [2, 3, 4],
    'num_leaves': [8, 16],
    'colsample_bytree' : [i / 10.0 for i in range(3, 11, 1)],
    'subsample' : [i / 10.0 for i in range(3, 11, 1)]
    }

# %%
def SubmissionSimple(data, submit=False):
  features = [x for x in data.columns if x not in drop_list]

  train = data[data.is_trade.notnull()]
  test = data[data.is_trade.isnull()]

  lgb_train = train[(train['day'] >= 18) & (train['day'] < 24)]
  lgb_valid = train[(train['day'] == 24)]

  lgb_train = lgb.Dataset(lgb_train[features], lgb_train[target], free_raw_data=False)
  lgb_valid = lgb.Dataset(lgb_valid[features], lgb_valid[target], reference=lgb_train, free_raw_data=False)

  print('\ntraining...')
  gbm = lgb.train(params=params, 
                  train_set=lgb_train,
                  valid_sets=[lgb_train, lgb_valid],
                  num_boost_round=10000, 
                  early_stopping_rounds=500,
                  verbose_eval=100)

  if submit:
    print('\npredicting...')
    test['predicted_score'] = gbm.predict(test[features], num_iteration=gbm.best_iteration)
    result = test[['instance_id', 'predicted_score']]
    result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
    print('\nsaving...')
    result.to_csv(wd+output_file, sep=' ', index=False)
    
  return gbm

# %%
from lightgbm import LGBMClassifier
from gossipcat import SimulatedAnneal

# %%
data = cloud_data

features = [x for x in data.columns if x not in drop_list]
train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]

target = 'is_trade'
drop_list = ['is_trade']
features = [x for x in data.columns if x not in drop_list]

gridParams = {
    'max_depth': [2, 3, 4],
    'num_leaves': [8, 16],
    'colsample_bytree' : [i / 20.0 for i in range(6, 21, 1)],
    'subsample' : [i / 20.0 for i in range(6, 21, 1)]
    }

mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = -1, 
          silent = True,
          random_state = 0,
          max_depth = params['max_depth'],
          num_leaves = params['num_leaves'], 
          colsample_bytree = params['colsample_bytree'],
          subsample = params['subsample'])

sim = SimulatedAnneal(mdl, gridParams,  scoring='neg_log_loss', alpha=0.75, n_trans=10, cv=4, verbose=True, random_state=0)

print('simulated annealing...')
# Run the grid
sim.fit(train[features], train[target])

# Using parameters already set above, replace in the best from the simulated annealing search
params['max_depth'] = sim.best_params_['max_depth']
params['num_leaves'] = sim.best_params_['num_leaves']
params['colsample_bytree'] = sim.best_params_['colsample_bytree']
params['subsample'] = sim.best_params_['subsample']

print('\nbest score:', '{:.6f}'.format(sim.best_score_), 
      '\nbest parameters:', str({key: '{:.3f}'.format(value) for key, value in sim.best_params_.items()}))
# Out:
# INFO: Number of possible iterations given cooling schedule: 400
#
# simulated annealing...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 2 T: 10.0, score: -0.0886, std: 0.0040, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.55', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 3 T: 10.0, score: -0.0885, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.50', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.3min finished
# 4 T: 10.0, score: -0.0884, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.50', 'subsample': '0.70'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.4min finished
# 5 T: 10.0, score: -0.0884, std: 0.0040, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.50', 'subsample': '0.70'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.5min finished
# 6 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.50', 'subsample': '0.80'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 7 T: 10.0, score: -0.0890, std: 0.0039, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.50', 'subsample': '0.80'}
# 8 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.50', 'subsample': '0.80'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.4min finished
# 9 T: 10.0, score: -0.0885, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.50', 'subsample': '0.80'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.5min finished
# 10 T: 10.0, score: -0.0884, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.50', 'subsample': '0.95'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.3min finished
# 11 T: 10.0, score: -0.0890, std: 0.0039, params: {'max_depth': '2.00', 'num_leaves': '8.00', 'colsample_bytree': '0.50', 'subsample': '0.95'}
#
# best score: -0.088308
# best parameters: {'max_depth': '4.000', 'num_leaves': '16.000', 'colsample_bytree': '0.500', 'subsample': '0.800'}

# %%
print('\npredicting...')
test['predicted_score'] = sim.best_estimator_.predict_proba(test[features])[:,1]
result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
print('\nsaving...')
result.to_csv(wd+output_file, sep=' ', index=False)
# Out:
# predicting...
#
# saving...

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt

# %matplotlib inline

lgb.plot_importance(sim.best_estimator_, figsize=(16,100))
plt.show()

# %%
for ind, col in enumerate(features):
    print(sim.best_estimator_.feature_importances_[ind], '\t', col)
# Out:
# 14 	 context_id
# 5 	 context_page_id
# 5 	 instance_id
# 4 	 item_brand_id
# 7 	 item_city_id
# 1 	 item_collected_level
# 8 	 item_id
# 48 	 item_price_level
# 0 	 item_pv_level
# 43 	 item_sales_level
# 2 	 shop_id
# 2 	 shop_review_num_level
# 5 	 shop_review_positive_rate
# 60 	 shop_score_delivery
# 12 	 shop_score_description
# 29 	 shop_score_service
# 0 	 shop_star_level
# 24 	 user_age_level
# 0 	 user_gender_id
# 1 	 user_id
# 2 	 user_occupation_id
# 4 	 user_star_level
# 3 	 len_item_category
# 20 	 len_item_property
# 23 	 item_category_list1
# 3 	 item_category_list2
# 3 	 item_property_list0
# 4 	 item_property_list1
# 3 	 item_property_list2
# 6 	 item_property_list3
# 7 	 item_property_list4
# 2 	 item_property_list5
# 0 	 item_property_list6
# 3 	 item_property_list7
# 9 	 item_property_list8
# 7 	 item_property_list9
# 0 	 gender0
# 0 	 age0
# 0 	 occupation0
# 0 	 star0
# 3 	 day
# 28 	 hour
# 1 	 len_predict_category_property
# 21 	 predict_category_property0
# 5 	 predict_category_property1
# 6 	 predict_category_property2
# 7 	 predict_category_property3
# 3 	 predict_category_property4
# 1 	 context_page0
# 0 	 shop_score_delivery0
# 21 	 hour_map
# 0 	 normal_shop
# 17 	 user_cnt1
# 5 	 item_cnt1
# 5 	 shop_cnt1
# 20 	 user_cntx
# 1 	 item_cntx
# 7 	 shop_cntx
# 31 	 sale_price
# 27 	 sale_collect
# 4 	 price_collect
# 8 	 gender_age
# 0 	 gender_occ
# 22 	 gender_star
# 4 	 user_gender_id_user_id_cnt
# 0 	 user_gender_id_user_id_prob
# 3 	 user_age_level_user_id_cnt
# 1 	 user_age_level_user_id_prob
# 2 	 user_occupation_id_user_id_cnt
# 0 	 user_occupation_id_user_id_prob
# 5 	 user_star_level_user_id_cnt
# 2 	 user_star_level_user_id_prob
# 0 	 user_age_level_user_gender_id_cnt
# 0 	 user_age_level_user_gender_id_prob
# 1 	 user_occupation_id_user_gender_id_cnt
# 3 	 user_occupation_id_user_gender_id_prob
# 2 	 user_star_level_user_gender_id_cnt
# 0 	 user_star_level_user_gender_id_prob
# 2 	 user_occupation_id_user_age_level_cnt
# 2 	 user_occupation_id_user_age_level_prob
# 10 	 user_star_level_user_age_level_cnt
# 14 	 user_star_level_user_age_level_prob
# 1 	 user_star_level_user_occupation_id_cnt
# 1 	 user_star_level_user_occupation_id_prob
# 2 	 item_brand_id_item_id_cnt
# 1 	 item_brand_id_item_id_prob
# 4 	 item_city_id_item_id_cnt
# 2 	 item_city_id_item_id_prob
# 0 	 item_price_level_item_id_cnt
# 0 	 item_price_level_item_id_prob
# 2 	 item_sales_level_item_id_cnt
# 6 	 item_sales_level_item_id_prob
# 3 	 item_collected_level_item_id_cnt
# 6 	 item_collected_level_item_id_prob
# 2 	 item_pv_level_item_id_cnt
# 0 	 item_pv_level_item_id_prob
# 4 	 item_city_id_item_brand_id_cnt
# 5 	 item_city_id_item_brand_id_prob
# 2 	 item_price_level_item_brand_id_cnt
# 4 	 item_price_level_item_brand_id_prob
# 2 	 item_sales_level_item_brand_id_cnt
# 5 	 item_sales_level_item_brand_id_prob
# 5 	 item_collected_level_item_brand_id_cnt
# 5 	 item_collected_level_item_brand_id_prob
# 3 	 item_pv_level_item_brand_id_cnt
# 4 	 item_pv_level_item_brand_id_prob
# 4 	 item_price_level_item_city_id_cnt
# 6 	 item_price_level_item_city_id_prob
# 5 	 item_sales_level_item_city_id_cnt
# 4 	 item_sales_level_item_city_id_prob
# 3 	 item_collected_level_item_city_id_cnt
# 5 	 item_collected_level_item_city_id_prob
# 3 	 item_pv_level_item_city_id_cnt
# 2 	 item_pv_level_item_city_id_prob
# 4 	 item_sales_level_item_price_level_cnt
# 7 	 item_sales_level_item_price_level_prob
# 1 	 item_collected_level_item_price_level_cnt
# 6 	 item_collected_level_item_price_level_prob
# 1 	 item_pv_level_item_price_level_cnt
# 1 	 item_pv_level_item_price_level_prob
# 7 	 item_collected_level_item_sales_level_cnt
# 33 	 item_collected_level_item_sales_level_prob
# 4 	 item_pv_level_item_sales_level_cnt
# 25 	 item_pv_level_item_sales_level_prob
# 7 	 item_pv_level_item_collected_level_cnt
# 3 	 item_pv_level_item_collected_level_prob
# 3 	 shop_review_num_level_shop_id_cnt
# 4 	 shop_review_num_level_shop_id_prob
# 4 	 shop_star_level_shop_id_cnt
# 4 	 shop_star_level_shop_id_prob
# 1 	 shop_star_level_shop_review_num_level_cnt
# 0 	 shop_star_level_shop_review_num_level_prob
# 7 	 item_id_user_id_cnt
# 50 	 item_id_user_id_prob
# 3 	 item_brand_id_user_id_cnt
# 31 	 item_brand_id_user_id_prob
# 1 	 item_city_id_user_id_cnt
# 12 	 item_city_id_user_id_prob
# 1 	 item_price_level_user_id_cnt
# 7 	 item_price_level_user_id_prob
# 2 	 item_sales_level_user_id_cnt
# 13 	 item_sales_level_user_id_prob
# 3 	 item_collected_level_user_id_cnt
# 7 	 item_collected_level_user_id_prob
# 2 	 item_pv_level_user_id_cnt
# 4 	 item_pv_level_user_id_prob
# 2 	 item_id_user_gender_id_cnt
# 1 	 item_id_user_gender_id_prob
# 4 	 item_brand_id_user_gender_id_cnt
# 3 	 item_brand_id_user_gender_id_prob
# 12 	 item_city_id_user_gender_id_cnt
# 4 	 item_city_id_user_gender_id_prob
# 0 	 item_price_level_user_gender_id_cnt
# 6 	 item_price_level_user_gender_id_prob
# 3 	 item_sales_level_user_gender_id_cnt
# 3 	 item_sales_level_user_gender_id_prob
# 3 	 item_collected_level_user_gender_id_cnt
# 0 	 item_collected_level_user_gender_id_prob
# 3 	 item_pv_level_user_gender_id_cnt
# 0 	 item_pv_level_user_gender_id_prob
# 3 	 item_id_user_age_level_cnt
# 1 	 item_id_user_age_level_prob
# 2 	 item_brand_id_user_age_level_cnt
# 5 	 item_brand_id_user_age_level_prob
# 3 	 item_city_id_user_age_level_cnt
# 9 	 item_city_id_user_age_level_prob
# 2 	 item_price_level_user_age_level_cnt
# 33 	 item_price_level_user_age_level_prob
# 4 	 item_sales_level_user_age_level_cnt
# 7 	 item_sales_level_user_age_level_prob
# 2 	 item_collected_level_user_age_level_cnt
# 4 	 item_collected_level_user_age_level_prob
# 3 	 item_pv_level_user_age_level_cnt
# 0 	 item_pv_level_user_age_level_prob
# 4 	 item_id_user_occupation_id_cnt
# 2 	 item_id_user_occupation_id_prob
# 0 	 item_brand_id_user_occupation_id_cnt
# 2 	 item_brand_id_user_occupation_id_prob
# 1 	 item_city_id_user_occupation_id_cnt
# 9 	 item_city_id_user_occupation_id_prob
# 3 	 item_price_level_user_occupation_id_cnt
# 11 	 item_price_level_user_occupation_id_prob
# 5 	 item_sales_level_user_occupation_id_cnt
# 3 	 item_sales_level_user_occupation_id_prob
# 1 	 item_collected_level_user_occupation_id_cnt
# 1 	 item_collected_level_user_occupation_id_prob
# 1 	 item_pv_level_user_occupation_id_cnt
# 2 	 item_pv_level_user_occupation_id_prob
# 1 	 shop_id_user_id_cnt
# 22 	 shop_id_user_id_prob
# 0 	 shop_review_num_level_user_id_cnt
# 9 	 shop_review_num_level_user_id_prob
# 5 	 shop_star_level_user_id_cnt
# 3 	 shop_star_level_user_id_prob
# 1 	 shop_id_user_gender_id_cnt
# 3 	 shop_id_user_gender_id_prob
# 2 	 shop_review_num_level_user_gender_id_cnt
# 7 	 shop_review_num_level_user_gender_id_prob
# 2 	 shop_star_level_user_gender_id_cnt
# 6 	 shop_star_level_user_gender_id_prob
# 4 	 shop_id_user_age_level_cnt
# 8 	 shop_id_user_age_level_prob
# 0 	 shop_review_num_level_user_age_level_cnt
# 2 	 shop_review_num_level_user_age_level_prob
# 1 	 shop_star_level_user_age_level_cnt
# 5 	 shop_star_level_user_age_level_prob
# 4 	 shop_id_user_occupation_id_cnt
# 3 	 shop_id_user_occupation_id_prob
# 1 	 shop_review_num_level_user_occupation_id_cnt
# 0 	 shop_review_num_level_user_occupation_id_prob
# 3 	 shop_star_level_user_occupation_id_cnt
# 2 	 shop_star_level_user_occupation_id_prob
# 1 	 item_id_shop_id_cnt
# 21 	 item_id_shop_id_prob
# 2 	 item_brand_id_shop_id_cnt
# 1 	 item_brand_id_shop_id_prob
# 4 	 item_city_id_shop_id_cnt
# 2 	 item_city_id_shop_id_prob
# 7 	 item_price_level_shop_id_cnt
# 3 	 item_price_level_shop_id_prob
# 5 	 item_sales_level_shop_id_cnt
# 4 	 item_sales_level_shop_id_prob
# 4 	 item_collected_level_shop_id_cnt
# 8 	 item_collected_level_shop_id_prob
# 3 	 item_pv_level_shop_id_cnt
# 6 	 item_pv_level_shop_id_prob
# 0 	 item_id_shop_review_num_level_cnt
# 8 	 item_id_shop_review_num_level_prob
# 2 	 item_brand_id_shop_review_num_level_cnt
# 2 	 item_brand_id_shop_review_num_level_prob
# 3 	 item_city_id_shop_review_num_level_cnt
# 5 	 item_city_id_shop_review_num_level_prob
# 2 	 item_price_level_shop_review_num_level_cnt
# 10 	 item_price_level_shop_review_num_level_prob
# 8 	 item_sales_level_shop_review_num_level_cnt
# 11 	 item_sales_level_shop_review_num_level_prob
# 5 	 item_collected_level_shop_review_num_level_cnt
# 2 	 item_collected_level_shop_review_num_level_prob
# 0 	 item_pv_level_shop_review_num_level_cnt
# 0 	 item_pv_level_shop_review_num_level_prob
# 45 	 user_pagerank
# 0 	 item_pagerank

# %%
feature_imp = pd.DataFrame()

feature_imp['feature'] = features
feature_imp['importance'] = sim.best_estimator_.feature_importances_

# %%
feature_imp.sort_values(by='importance', ascending=False)
# Out:
#                                            feature  importance
# 13                             shop_score_delivery          60
# 133                           item_id_user_id_prob          50
# 7                                 item_price_level          48
# 240                                  user_pagerank          45
# 9                                 item_sales_level          43
# 121     item_collected_level_item_sales_level_prob          33
# 167           item_price_level_user_age_level_prob          33
# 135                     item_brand_id_user_id_prob          31
# 58                                      sale_price          31
# 15                              shop_score_service          29
# 41                                            hour          28
# 59                                    sale_collect          27
# 123            item_pv_level_item_sales_level_prob          25
# 17                                  user_age_level          24
# 24                             item_category_list1          23
# 63                                     gender_star          22
# 189                           shop_id_user_id_prob          22
# 50                                        hour_map          21
# 43                      predict_category_property0          21
# 213                           item_id_shop_id_prob          21
# 55                                       user_cntx          20
# 23                               len_item_property          20
# 52                                       user_cnt1          17
# 81             user_star_level_user_age_level_prob          14
# 0                                       context_id          14
# 141                  item_sales_level_user_id_prob          13
# 14                          shop_score_description          12
# 137                      item_city_id_user_id_prob          12
# 150                item_city_id_user_gender_id_cnt          12
# 235    item_sales_level_shop_review_num_level_prob          11
# ..                                             ...         ...
# 239       item_pv_level_shop_review_num_level_prob           0
# 8                                    item_pv_level           0
# 209  shop_review_num_level_user_occupation_id_prob           0
# 202       shop_review_num_level_user_age_level_cnt           0
# 32                             item_property_list6           0
# 36                                         gender0           0
# 37                                            age0           0
# 38                                     occupation0           0
# 39                                           star0           0
# 49                            shop_score_delivery0           0
# 51                                     normal_shop           0
# 18                                  user_gender_id           0
# 16                                 shop_star_level           0
# 62                                      gender_occ           0
# 65                     user_gender_id_user_id_prob           0
# 69                 user_occupation_id_user_id_prob           0
# 72               user_age_level_user_gender_id_cnt           0
# 73              user_age_level_user_gender_id_prob           0
# 77             user_star_level_user_gender_id_prob           0
# 88                    item_price_level_item_id_cnt           0
# 89                   item_price_level_item_id_prob           0
# 95                      item_pv_level_item_id_prob           0
# 131     shop_star_level_shop_review_num_level_prob           0
# 152            item_price_level_user_gender_id_cnt           0
# 157       item_collected_level_user_gender_id_prob           0
# 159              item_pv_level_user_gender_id_prob           0
# 173              item_pv_level_user_age_level_prob           0
# 176           item_brand_id_user_occupation_id_cnt           0
# 190              shop_review_num_level_user_id_cnt           0
# 241                                  item_pagerank           0
#
# [242 rows x 2 columns]

# %%
feature_imp.sort_values(by='importance', ascending=False).hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x190ebc710>]],
#       dtype=object)

# %%
drop_list = feature_imp[(feature_imp.importance < 1)]['feature'].tolist()

# %%
drop_list
# Out:
# ['item_pv_level',
#  'shop_star_level',
#  'user_gender_id',
#  'item_property_list6',
#  'gender0',
#  'age0',
#  'occupation0',
#  'star0',
#  'shop_score_delivery0',
#  'normal_shop',
#  'gender_occ',
#  'user_gender_id_user_id_prob',
#  'user_occupation_id_user_id_prob',
#  'user_age_level_user_gender_id_cnt',
#  'user_age_level_user_gender_id_prob',
#  'user_star_level_user_gender_id_prob',
#  'item_price_level_item_id_cnt',
#  'item_price_level_item_id_prob',
#  'item_pv_level_item_id_prob',
#  'shop_star_level_shop_review_num_level_prob',
#  'item_price_level_user_gender_id_cnt',
#  'item_collected_level_user_gender_id_prob',
#  'item_pv_level_user_gender_id_prob',
#  'item_pv_level_user_age_level_prob',
#  'item_brand_id_user_occupation_id_cnt',
#  'shop_review_num_level_user_id_cnt',
#  'shop_review_num_level_user_age_level_cnt',
#  'shop_review_num_level_user_occupation_id_prob',
#  'item_id_shop_review_num_level_cnt',
#  'item_pv_level_shop_review_num_level_cnt',
#  'item_pv_level_shop_review_num_level_prob',
#  'item_pagerank']

# %%
flower_data = cloud_data.drop(drop_list, axis=1)

# %%
flower_data.head()
# Out:
#             context_id  context_page_id          instance_id  is_trade  \
# 0   282924576738839389             4006   108641074714126964       0.0
# 1  4007979028023783431             4001  5754713551599725161       0.0
# 2  4884875192608989870             4001   842679481291040981       0.0
# 3   840119421106178602             4016   937088850059189027       0.0
# 4  1736769971710354684             4001  7975697065017708072       0.0
#
#    item_brand_id  item_city_id  item_collected_level  item_id  \
# 0            453            50                     4     3804
# 1            453            50                     4     3804
# 2            453            50                     4     3804
# 3            453            50                     4     3804
# 4            453            50                     4     3804
#
#    item_price_level  item_sales_level      ...        \
# 0                 3                 3      ...
# 1                 3                 3      ...
# 2                 3                 3      ...
# 3                 3                 3      ...
# 4                 3                 3      ...
#
#    item_brand_id_shop_review_num_level_prob  \
# 0                                  0.055351
# 1                                  0.055351
# 2                                  0.055351
# 3                                  0.055351
# 4                                  0.055351
#
#    item_city_id_shop_review_num_level_cnt  \
# 0                                      37
# 1                                      37
# 2                                      37
# 3                                      37
# 4                                      37
#
#    item_city_id_shop_review_num_level_prob  \
# 0                                 0.136531
# 1                                 0.136531
# 2                                 0.136531
# 3                                 0.136531
# 4                                 0.136531
#
#    item_price_level_shop_review_num_level_cnt  \
# 0                                          24
# 1                                          24
# 2                                          24
# 3                                          24
# 4                                          24
#
#    item_price_level_shop_review_num_level_prob  \
# 0                                     0.088561
# 1                                     0.088561
# 2                                     0.088561
# 3                                     0.088561
# 4                                     0.088561
#
#    item_sales_level_shop_review_num_level_cnt  \
# 0                                          64
# 1                                          64
# 2                                          64
# 3                                          64
# 4                                          64
#
#    item_sales_level_shop_review_num_level_prob  \
# 0                                     0.236162
# 1                                     0.236162
# 2                                     0.236162
# 3                                     0.236162
# 4                                     0.236162
#
#    item_collected_level_shop_review_num_level_cnt  \
# 0                                              46
# 1                                              46
# 2                                              46
# 3                                              46
# 4                                              46
#
#    item_collected_level_shop_review_num_level_prob  user_pagerank
# 0                                         0.169742       0.000010
# 1                                         0.169742       0.000010
# 2                                         0.169742       0.000003
# 3                                         0.169742       0.000002
# 4                                         0.169742       0.000003
#
# [5 rows x 211 columns]

# %%
flower_data.shape
# Out:
# (496449, 211)

# %%
flower_data.to_csv(wd+'flower_data.txt', sep=' ', index=False)

# %% [markdown]
# ## results 28

# %%
data = flower_data

train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]

target = 'is_trade'
drop_list = ['is_trade']
features = [x for x in data.columns if x not in drop_list]

gridParams = {
    'max_depth': [2, 3, 4],
    'num_leaves': [8, 16],
    'colsample_bytree' : [i / 20.0 for i in range(6, 21, 1)],
    'subsample' : [i / 20.0 for i in range(6, 21, 1)]
    }

mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = -1, 
          silent = True,
          random_state = 0,
          max_depth = params['max_depth'],
          num_leaves = params['num_leaves'], 
          colsample_bytree = params['colsample_bytree'],
          subsample = params['subsample'])

sim = SimulatedAnneal(mdl, gridParams,  scoring='neg_log_loss', alpha=0.75, n_trans=10, cv=4, verbose=True, random_state=0)

print('simulated annealing...')
# Run the grid
sim.fit(train[features], train[target])

# Using parameters already set above, replace in the best from the simulated annealing search
params['max_depth'] = sim.best_params_['max_depth']
params['num_leaves'] = sim.best_params_['num_leaves']
params['colsample_bytree'] = sim.best_params_['colsample_bytree']
params['subsample'] = sim.best_params_['subsample']

print('\nbest score:', '{:.6f}'.format(sim.best_score_), 
      '\nbest parameters:', str({key: '{:.3f}'.format(value) for key, value in sim.best_params_.items()}))
# Out:
# INFO: Number of possible iterations given cooling schedule: 400
#
# simulated annealing...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.4min finished
# 2 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.90'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.4min finished
# 3 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.75', 'subsample': '0.90'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 4 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.75', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 5 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.40', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.0min finished
# 6 T: 10.0, score: -0.0889, std: 0.0039, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.40', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   58.7s finished
# 7 T: 10.0, score: -0.0889, std: 0.0038, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  3.2min finished
# 8 T: 10.0, score: -0.0885, std: 0.0039, params: {'max_depth': '3.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 9 T: 10.0, score: -0.0884, std: 0.0040, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# 10 T: 10.0, score: -0.0889, std: 0.0038, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   57.9s finished
# 11 T: 10.0, score: -0.0889, std: 0.0038, params: {'max_depth': '2.00', 'num_leaves': '8.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
#
# best score: -0.088269
# best parameters: {'max_depth': '4.000', 'num_leaves': '16.000', 'colsample_bytree': '0.700', 'subsample': '0.900'}

# %%
print('\npredicting...')
test['predicted_score'] = sim.best_estimator_.predict_proba(test[features])[:,1]
result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
print('\nsaving...')
result.to_csv(wd+output_file, sep=' ', index=False)
# Out:
# predicting...
#
# saving...

# %%
lgb.plot_importance(sim.best_estimator_, figsize=(16,30))
plt.show()

# %%
feature_imp = pd.DataFrame()

feature_imp['feature'] = features
feature_imp['importance'] = sim.best_estimator_.feature_importances_

# %%
feature_imp.sort_values(by='importance', ascending=False)
# Out:
#                                              feature  importance
# 12                               shop_score_delivery          82
# 209                                    user_pagerank          64
# 7                                   item_price_level          50
# 8                                   item_sales_level          48
# 113                             item_id_user_id_prob          46
# 115                       item_brand_id_user_id_prob          37
# 48                                        sale_price          32
# 33                                              hour          31
# 144             item_price_level_user_age_level_prob          29
# 102       item_collected_level_item_sales_level_prob          28
# 164                             shop_id_user_id_prob          27
# 14                                shop_score_service          27
# 15                                    user_age_level          25
# 35                        predict_category_property0          24
# 104              item_pv_level_item_sales_level_prob          24
# 21                               item_category_list1          24
# 41                                          hour_map          23
# 49                                      sale_collect          20
# 45                                         user_cntx          20
# 20                                 len_item_property          20
# 42                                         user_cnt1          19
# 185                             item_id_shop_id_prob          18
# 52                                       gender_star          17
# 65               user_star_level_user_age_level_prob          16
# 0                                         context_id          14
# 11                         shop_review_positive_rate          14
# 121                    item_sales_level_user_id_prob          13
# 2                                        instance_id          12
# 30                               item_property_list8          12
# 47                                         shop_cntx          11
# ..                                               ...         ...
# 208  item_collected_level_shop_review_num_level_prob           1
# 184                              item_id_shop_id_cnt           1
# 161             item_pv_level_user_occupation_id_cnt           1
# 109                      shop_star_level_shop_id_cnt           1
# 10                             shop_review_num_level           1
# 120                     item_sales_level_user_id_cnt           1
# 114                        item_brand_id_user_id_cnt           1
# 167                     shop_star_level_user_id_prob           1
# 110                     shop_star_level_shop_id_prob           1
# 181     shop_review_num_level_user_occupation_id_cnt           1
# 172               shop_star_level_user_gender_id_cnt           1
# 128                 item_brand_id_user_gender_id_cnt           1
# 140                item_brand_id_user_age_level_prob           1
# 92            item_collected_level_item_city_id_prob           1
# 99                item_pv_level_item_price_level_cnt           1
# 100              item_pv_level_item_price_level_prob           0
# 54                        user_age_level_user_id_cnt           0
# 148         item_collected_level_user_age_level_prob           0
# 118                     item_price_level_user_id_cnt           0
# 149                 item_pv_level_user_age_level_cnt           0
# 77                    item_city_id_item_brand_id_cnt           0
# 166                      shop_star_level_user_id_cnt           0
# 139                 item_brand_id_user_age_level_cnt           0
# 200         item_brand_id_shop_review_num_level_prob           0
# 168                       shop_id_user_gender_id_cnt           0
# 69                        item_brand_id_item_id_prob           0
# 60            user_occupation_id_user_gender_id_prob           0
# 189                        item_city_id_shop_id_prob           0
# 152            item_brand_id_user_occupation_id_prob           0
# 182           shop_star_level_user_occupation_id_cnt           0
#
# [210 rows x 2 columns]

# %%
drop_list = feature_imp[(feature_imp.importance < 1)]['feature'].tolist()

# %%
drop_list
# Out:
# ['user_age_level_user_id_cnt',
#  'user_occupation_id_user_gender_id_prob',
#  'item_brand_id_item_id_prob',
#  'item_city_id_item_brand_id_cnt',
#  'item_pv_level_item_price_level_prob',
#  'item_price_level_user_id_cnt',
#  'item_brand_id_user_age_level_cnt',
#  'item_collected_level_user_age_level_prob',
#  'item_pv_level_user_age_level_cnt',
#  'item_brand_id_user_occupation_id_prob',
#  'shop_star_level_user_id_cnt',
#  'shop_id_user_gender_id_cnt',
#  'shop_star_level_user_occupation_id_cnt',
#  'item_city_id_shop_id_prob',
#  'item_brand_id_shop_review_num_level_prob']

# %%
bean_data = flower_data.drop(drop_list, axis=1)

# %%
bean_data.shape
# Out:
# (496449, 196)

# %%
bean_data.head()
# Out:
#             context_id  context_page_id          instance_id  is_trade  \
# 0   282924576738839389             4006   108641074714126964       0.0
# 1  4007979028023783431             4001  5754713551599725161       0.0
# 2  4884875192608989870             4001   842679481291040981       0.0
# 3   840119421106178602             4016   937088850059189027       0.0
# 4  1736769971710354684             4001  7975697065017708072       0.0
#
#    item_brand_id  item_city_id  item_collected_level  item_id  \
# 0            453            50                     4     3804
# 1            453            50                     4     3804
# 2            453            50                     4     3804
# 3            453            50                     4     3804
# 4            453            50                     4     3804
#
#    item_price_level  item_sales_level      ...        \
# 0                 3                 3      ...
# 1                 3                 3      ...
# 2                 3                 3      ...
# 3                 3                 3      ...
# 4                 3                 3      ...
#
#    item_brand_id_shop_review_num_level_cnt  \
# 0                                       15
# 1                                       15
# 2                                       15
# 3                                       15
# 4                                       15
#
#    item_city_id_shop_review_num_level_cnt  \
# 0                                      37
# 1                                      37
# 2                                      37
# 3                                      37
# 4                                      37
#
#    item_city_id_shop_review_num_level_prob  \
# 0                                 0.136531
# 1                                 0.136531
# 2                                 0.136531
# 3                                 0.136531
# 4                                 0.136531
#
#    item_price_level_shop_review_num_level_cnt  \
# 0                                          24
# 1                                          24
# 2                                          24
# 3                                          24
# 4                                          24
#
#    item_price_level_shop_review_num_level_prob  \
# 0                                     0.088561
# 1                                     0.088561
# 2                                     0.088561
# 3                                     0.088561
# 4                                     0.088561
#
#    item_sales_level_shop_review_num_level_cnt  \
# 0                                          64
# 1                                          64
# 2                                          64
# 3                                          64
# 4                                          64
#
#    item_sales_level_shop_review_num_level_prob  \
# 0                                     0.236162
# 1                                     0.236162
# 2                                     0.236162
# 3                                     0.236162
# 4                                     0.236162
#
#    item_collected_level_shop_review_num_level_cnt  \
# 0                                              46
# 1                                              46
# 2                                              46
# 3                                              46
# 4                                              46
#
#    item_collected_level_shop_review_num_level_prob  user_pagerank
# 0                                         0.169742       0.000010
# 1                                         0.169742       0.000010
# 2                                         0.169742       0.000003
# 3                                         0.169742       0.000002
# 4                                         0.169742       0.000003
#
# [5 rows x 196 columns]

# %%
bean_data.to_csv(wd+'bean_data.txt', sep=' ', index=False)

# %% [markdown]
# ## results 29

# %%
data = bean_data

# %%
train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]

target = 'is_trade'
drop_list = ['is_trade']
features = [x for x in data.columns if x not in drop_list]

gridParams = {
    'max_depth': [2, 3, 4],
    'num_leaves': [8, 16],
    'colsample_bytree' : [i / 20.0 for i in range(6, 21, 1)],
    'subsample' : [i / 20.0 for i in range(6, 21, 1)]
    }

mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = -1, 
          silent = True,
          random_state = 0,
          max_depth = params['max_depth'],
          num_leaves = params['num_leaves'], 
          colsample_bytree = params['colsample_bytree'],
          subsample = params['subsample'])

sim = SimulatedAnneal(mdl, gridParams,  scoring='neg_log_loss', alpha=0.75, n_trans=10, cv=4, verbose=True, random_state=0)

print('simulated annealing...')
# Run the grid
sim.fit(train[features], train[target])

# Using parameters already set above, replace in the best from the simulated annealing search
params['max_depth'] = sim.best_params_['max_depth']
params['num_leaves'] = sim.best_params_['num_leaves']
params['colsample_bytree'] = sim.best_params_['colsample_bytree']
params['subsample'] = sim.best_params_['subsample']

print('\nbest score:', '{:.6f}'.format(sim.best_score_), 
      '\nbest parameters:', str({key: '{:.3f}'.format(value) for key, value in sim.best_params_.items()}))

print('\npredicting...')
test['predicted_score'] = sim.best_estimator_.predict_proba(test[features])[:,1]
result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
print('\nsaving...')
result.to_csv(wd+output_file, sep=' ', index=False)

print('\nplotting...')
lgb.plot_importance(sim.best_estimator_, figsize=(16,30))
plt.show()

feature_imp = pd.DataFrame()

feature_imp['feature'] = features
feature_imp['importance'] = sim.best_estimator_.feature_importances_
# Out:
# INFO: Number of possible iterations given cooling schedule: 400
#
# simulated annealing...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   55.3s finished
# 2 T: 10.0, score: -0.0889, std: 0.0039, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.65', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.1min finished
# 3 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.65', 'subsample': '0.75'}
# 4 T: 10.0, score: -0.0889, std: 0.0039, params: {'max_depth': '2.00', 'num_leaves': '16.00', 'colsample_bytree': '0.65', 'subsample': '0.75'}
# 5 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.65', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.1min finished
# 6 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.80', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.1min finished
# 7 T: 10.0, score: -0.0883, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '16.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.1min finished
# 8 T: 10.0, score: -0.0884, std: 0.0039, params: {'max_depth': '4.00', 'num_leaves': '8.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.0min finished
# 9 T: 10.0, score: -0.0884, std: 0.0039, params: {'max_depth': '3.00', 'num_leaves': '8.00', 'colsample_bytree': '0.70', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 10 T: 10.0, score: -0.0884, std: 0.0039, params: {'max_depth': '3.00', 'num_leaves': '8.00', 'colsample_bytree': '0.70', 'subsample': '0.95'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.2min finished
# 11 T: 10.0, score: -0.0885, std: 0.0039, params: {'max_depth': '3.00', 'num_leaves': '8.00', 'colsample_bytree': '0.35', 'subsample': '0.95'}
#
# best score: -0.088269
# best parameters: {'max_depth': '4.000', 'num_leaves': '16.000', 'colsample_bytree': '0.700', 'subsample': '0.750'}
#
# predicting...
#
# saving...
#
# plotting...

# %%
feature_imp.sort_values(by='importance', ascending=False)
# Out:
#                                              feature  importance
# 12                               shop_score_delivery          67
# 108                             item_id_user_id_prob          66
# 194                                    user_pagerank          52
# 7                                   item_price_level          42
# 8                                   item_sales_level          37
# 14                                shop_score_service          35
# 137             item_price_level_user_age_level_prob          33
# 33                                              hour          32
# 97        item_collected_level_item_sales_level_prob          32
# 110                       item_brand_id_user_id_prob          29
# 49                                      sale_collect          27
# 45                                         user_cntx          25
# 35                        predict_category_property0          24
# 20                                 len_item_property          23
# 21                               item_category_list1          23
# 63               user_star_level_user_age_level_prob          22
# 41                                          hour_map          21
# 48                                        sale_price          20
# 99               item_pv_level_item_sales_level_prob          19
# 15                                    user_age_level          18
# 154                             shop_id_user_id_prob          18
# 172                             item_id_shop_id_prob          18
# 42                                         user_cnt1          17
# 52                                       gender_star          16
# 112                        item_city_id_user_id_prob          15
# 135                 item_city_id_user_age_level_prob          13
# 11                         shop_review_positive_rate          12
# 115                    item_sales_level_user_id_prob          12
# 50                                     price_collect          12
# 187          item_city_id_shop_review_num_level_prob          11
# ..                                               ...         ...
# 182                        item_pv_level_shop_id_cnt           1
# 122                 item_brand_id_user_gender_id_cnt           1
# 1                                    context_page_id           1
# 179                    item_sales_level_shop_id_prob           1
# 193  item_collected_level_shop_review_num_level_prob           1
# 95                item_pv_level_item_price_level_cnt           1
# 93         item_collected_level_item_price_level_cnt           1
# 114                     item_sales_level_user_id_cnt           1
# 111                         item_city_id_user_id_cnt           1
# 153                              shop_id_user_id_cnt           1
# 77                item_sales_level_item_brand_id_cnt           1
# 134                  item_city_id_user_age_level_cnt           1
# 169     shop_review_num_level_user_occupation_id_cnt           1
# 71                  item_collected_level_item_id_cnt           1
# 167                   shop_id_user_occupation_id_cnt           1
# 4                                       item_city_id           1
# 78               item_sales_level_item_brand_id_prob           1
# 164        shop_review_num_level_user_age_level_prob           1
# 67                          item_city_id_item_id_cnt           1
# 34                     len_predict_category_property           1
# 188       item_price_level_shop_review_num_level_cnt           0
# 66                         item_brand_id_item_id_cnt           0
# 118                        item_pv_level_user_id_cnt           0
# 17                                user_occupation_id           0
# 105                     shop_star_level_shop_id_prob           0
# 171                              item_id_shop_id_cnt           0
# 64            user_star_level_user_occupation_id_cnt           0
# 168                  shop_id_user_occupation_id_prob           0
# 58             user_occupation_id_user_gender_id_cnt           0
# 129          item_collected_level_user_gender_id_cnt           0
#
# [195 rows x 2 columns]

# %%
drop_list = feature_imp[(feature_imp.importance < 1)]['feature'].tolist()
drop_list
# Out:
# ['user_occupation_id',
#  'user_occupation_id_user_gender_id_cnt',
#  'user_star_level_user_occupation_id_cnt',
#  'item_brand_id_item_id_cnt',
#  'shop_star_level_shop_id_prob',
#  'item_pv_level_user_id_cnt',
#  'item_collected_level_user_gender_id_cnt',
#  'shop_id_user_occupation_id_prob',
#  'item_id_shop_id_cnt',
#  'item_price_level_shop_review_num_level_cnt']

# %%
tree_data = bean_data.drop(drop_list, axis=1)
print(tree_data.shape)
# Out:
# (496449, 186)

# %%
tree_data.head()
# Out:
#             context_id  context_page_id          instance_id  is_trade  \
# 0   282924576738839389             4006   108641074714126964       0.0
# 1  4007979028023783431             4001  5754713551599725161       0.0
# 2  4884875192608989870             4001   842679481291040981       0.0
# 3   840119421106178602             4016   937088850059189027       0.0
# 4  1736769971710354684             4001  7975697065017708072       0.0
#
#    item_brand_id  item_city_id  item_collected_level  item_id  \
# 0            453            50                     4     3804
# 1            453            50                     4     3804
# 2            453            50                     4     3804
# 3            453            50                     4     3804
# 4            453            50                     4     3804
#
#    item_price_level  item_sales_level      ...        \
# 0                 3                 3      ...
# 1                 3                 3      ...
# 2                 3                 3      ...
# 3                 3                 3      ...
# 4                 3                 3      ...
#
#    item_id_shop_review_num_level_prob  \
# 0                            0.055351
# 1                            0.055351
# 2                            0.055351
# 3                            0.055351
# 4                            0.055351
#
#    item_brand_id_shop_review_num_level_cnt  \
# 0                                       15
# 1                                       15
# 2                                       15
# 3                                       15
# 4                                       15
#
#    item_city_id_shop_review_num_level_cnt  \
# 0                                      37
# 1                                      37
# 2                                      37
# 3                                      37
# 4                                      37
#
#    item_city_id_shop_review_num_level_prob  \
# 0                                 0.136531
# 1                                 0.136531
# 2                                 0.136531
# 3                                 0.136531
# 4                                 0.136531
#
#    item_price_level_shop_review_num_level_prob  \
# 0                                     0.088561
# 1                                     0.088561
# 2                                     0.088561
# 3                                     0.088561
# 4                                     0.088561
#
#    item_sales_level_shop_review_num_level_cnt  \
# 0                                          64
# 1                                          64
# 2                                          64
# 3                                          64
# 4                                          64
#
#    item_sales_level_shop_review_num_level_prob  \
# 0                                     0.236162
# 1                                     0.236162
# 2                                     0.236162
# 3                                     0.236162
# 4                                     0.236162
#
#    item_collected_level_shop_review_num_level_cnt  \
# 0                                              46
# 1                                              46
# 2                                              46
# 3                                              46
# 4                                              46
#
#    item_collected_level_shop_review_num_level_prob  user_pagerank
# 0                                         0.169742       0.000010
# 1                                         0.169742       0.000010
# 2                                         0.169742       0.000003
# 3                                         0.169742       0.000002
# 4                                         0.169742       0.000003
#
# [5 rows x 186 columns]

# %%
tree_data.to_csv(wd+'tree_data.txt', sep=' ', index=False)

# %% [markdown]
# ## results 30

# %%
cvr_sm = 'cvr_bayesianSM.txt'

data = pd.read_csv(wd+file_UISC, sep=' ')
data = data.merge(pd.read_csv(wd+cvr_sm, sep=' '), on='instance_id', how='left').merge(pd.read_csv(wd+pagerank, sep=' '), on='instance_id', how='left')

# %%
def Submission(data, submit=False):
    
    params = {'boosting_type': 'gbdt',
          'max_depth' : 2,
          'objective': 'binary', 
          'num_leaves': 4, 
          'learning_rate': 0.01, 
          'subsample': 0.6, 
          'colsample_bytree': 0.8, 
          'metric' : 'binary_logloss'}
    
    gridParams = {
      'max_depth': [i for i in range(3, 8, 1)],
      'colsample_bytree' : [i / 10.0 for i in range(3, 11, 1)],
      'subsample' : [i / 10.0 for i in range(6, 11, 1)]
    }
    target = 'is_trade'
    drop_list = ['is_trade', 'item_category_list', 'item_property_list', 'predict_category_property', 'realtime', 'context_timestamp', 'Unnamed: 0']
    features = [x for x in data.columns if x not in drop_list]

    if submit:
        train = data[data.is_trade.notnull()]
        test = data[data.is_trade.isnull()]
    else:
        test_day = 24
        train = data[(data['day'] >= 18) & (data['day'] < test_day)]
        test = data[(data['day'] == test_day)]

    mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
              objective = 'binary', 
              n_jobs = -1, 
              silent = True,
              random_state = 0,
              max_depth = params['max_depth'],
              colsample_bytree = params['colsample_bytree'],
              subsample = params['subsample'])

    sim = SimulatedAnneal(mdl, gridParams,  scoring='neg_log_loss', alpha=0.75, n_trans=10, cv=4, verbose=True, random_state=0)

    print('simulated annealing...')
    sim.fit(train[features], train[target])

    # Using parameters already set above, replace in the best from the simulated annealing search
    params['max_depth'] = sim.best_params_['max_depth']
    params['colsample_bytree'] = sim.best_params_['colsample_bytree']
    params['subsample'] = sim.best_params_['subsample']

    print('\nbest score:', '{:.6f}'.format(sim.best_score_), 
          '\nbest parameters:', str({key: '{:.3f}'.format(value) for key, value in sim.best_params_.items()}))

    print('predicting...')
    test['predicted_score'] = sim.best_estimator_.predict_proba(test[features])[:,1]
    
    if submit:
        result = test[['instance_id', 'predicted_score']]
        result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
        print('\nsaving...')
        result.to_csv(wd+output_file, sep=' ', index=False)
    else:
        print('Log loss: ', log_loss(test['is_trade'], test['predicted_score']))   
    
    return None

# %%
import pandas as pd 
import lightgbm as lgb
from sklearn.metrics import log_loss
from gossipcat import SimulatedAnneal
import warnings

warnings.filterwarnings('ignore')

Submission(data)
# Out:
# WARNING: The value for max_iter=300 does not constrain the number of iterations for the specified cooling schedule (200).  Setting max_iter=200
#
# INFO: Number of possible iterations given cooling schedule: 200
#
# simulated annealing...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.6min finished
# 2 T: 10.0, score: -0.0902, std: 0.0026, params: {'max_depth': '14.00', 'colsample_bytree': '0.90', 'subsample': '0.90'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.0min finished
# 3 T: 10.0, score: -0.0895, std: 0.0024, params: {'max_depth': '4.00', 'colsample_bytree': '0.90', 'subsample': '0.90'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.9min finished
# 4 T: 10.0, score: -0.0895, std: 0.0024, params: {'max_depth': '4.00', 'colsample_bytree': '0.90', 'subsample': '0.75'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.9min finished
# 5 T: 10.0, score: -0.0895, std: 0.0024, params: {'max_depth': '4.00', 'colsample_bytree': '0.90', 'subsample': '0.80'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.3min finished
# 6 T: 10.0, score: -0.0903, std: 0.0026, params: {'max_depth': '12.00', 'colsample_bytree': '0.90', 'subsample': '0.80'}
#
# best score: -0.089475
# best parameters: {'max_depth': '4.000', 'colsample_bytree': '0.900', 'subsample': '0.900'}
# predicting...
# Log loss:  0.08154126530639891

# %%
test_file = 'round1_ijcai_18_test_a_20180301.txt'
output_file = 'result.txt'

Submission(data, submit=True)
# Out:
# INFO: Number of possible iterations given cooling schedule: 400
#
# simulated annealing...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.3min finished
# 2 T: 10.0, score: -0.0888, std: 0.0039, params: {'max_depth': '5.00', 'colsample_bytree': '0.50', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.1min finished
# 3 T: 10.0, score: -0.0888, std: 0.0039, params: {'max_depth': '5.00', 'colsample_bytree': '0.60', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 39.9min finished
# 4 T: 10.0, score: -0.0890, std: 0.0041, params: {'max_depth': '5.00', 'colsample_bytree': '0.40', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.9min finished
# 5 T: 10.0, score: -0.0889, std: 0.0041, params: {'max_depth': '4.00', 'colsample_bytree': '0.40', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.8min finished
# 6 T: 10.0, score: -0.0887, std: 0.0040, params: {'max_depth': '4.00', 'colsample_bytree': '0.80', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.8min finished
# 7 T: 10.0, score: -0.0887, std: 0.0040, params: {'max_depth': '4.00', 'colsample_bytree': '0.90', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.8min finished
# 8 T: 10.0, score: -0.0887, std: 0.0039, params: {'max_depth': '4.00', 'colsample_bytree': '0.60', 'subsample': '0.60'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.2min finished
# 9 T: 10.0, score: -0.0886, std: 0.0039, params: {'max_depth': '4.00', 'colsample_bytree': '0.60', 'subsample': '0.90'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.2min finished
# 10 T: 10.0, score: -0.0887, std: 0.0041, params: {'max_depth': '4.00', 'colsample_bytree': '0.60', 'subsample': '0.80'}
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.8min finished
# 11 T: 10.0, score: -0.0888, std: 0.0039, params: {'max_depth': '3.00', 'colsample_bytree': '0.60', 'subsample': '0.80'}
#
# best score: -0.088633
# best parameters: {'max_depth': '4.000', 'colsample_bytree': '0.600', 'subsample': '0.900'}
# predicting...
#
# saving...

# %% [markdown]
# ## results 31

# %%
train= data[(data['day'] >= 18) & (data['day'] <= 23)]
test= data[(data['day'] == 24)]

target = 'is_trade'
drop_list = ['is_trade', 'item_category_list', 'item_property_list', 'predict_category_property', 'realtime', 'context_timestamp', 'Unnamed: 0']
features = [x for x in data.columns if x not in drop_list]

X = train[features]
y = train[target].values
X_tes = test[features]
y_tes = test[target].values

print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=16,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=20000,
    silent = True)

lgb_model = lgb0.fit(X, y, eval_set=[(X_tes, y_tes)], early_stopping_rounds=200)
# Out:
# Training LGBM model...
# [1]	valid_0's binary_logloss: 0.683893
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.674824
# [3]	valid_0's binary_logloss: 0.665931
# [4]	valid_0's binary_logloss: 0.657211
# [5]	valid_0's binary_logloss: 0.648661
# [6]	valid_0's binary_logloss: 0.640271
# [7]	valid_0's binary_logloss: 0.632041
# [8]	valid_0's binary_logloss: 0.623962
# [9]	valid_0's binary_logloss: 0.616037
# [10]	valid_0's binary_logloss: 0.608257
# [11]	valid_0's binary_logloss: 0.600617
# [12]	valid_0's binary_logloss: 0.593117
# [13]	valid_0's binary_logloss: 0.585757
# [14]	valid_0's binary_logloss: 0.578527
# [15]	valid_0's binary_logloss: 0.571422
# [16]	valid_0's binary_logloss: 0.564445
# [17]	valid_0's binary_logloss: 0.557589
# [18]	valid_0's binary_logloss: 0.550855
# [19]	valid_0's binary_logloss: 0.544236
# [20]	valid_0's binary_logloss: 0.537731
# [21]	valid_0's binary_logloss: 0.531336
# [22]	valid_0's binary_logloss: 0.525049
# [23]	valid_0's binary_logloss: 0.518869
# [24]	valid_0's binary_logloss: 0.512792
# [25]	valid_0's binary_logloss: 0.506819
# [26]	valid_0's binary_logloss: 0.500943
# [27]	valid_0's binary_logloss: 0.495164
# [28]	valid_0's binary_logloss: 0.489479
# [29]	valid_0's binary_logloss: 0.483885
# [30]	valid_0's binary_logloss: 0.478382
# [31]	valid_0's binary_logloss: 0.472967
# [32]	valid_0's binary_logloss: 0.46764
# [33]	valid_0's binary_logloss: 0.462399
# [34]	valid_0's binary_logloss: 0.457243
# [35]	valid_0's binary_logloss: 0.452163
# [36]	valid_0's binary_logloss: 0.447165
# [37]	valid_0's binary_logloss: 0.442242
# [38]	valid_0's binary_logloss: 0.437401
# [39]	valid_0's binary_logloss: 0.432631
# [40]	valid_0's binary_logloss: 0.427937
# [41]	valid_0's binary_logloss: 0.423312
# [42]	valid_0's binary_logloss: 0.418759
# [43]	valid_0's binary_logloss: 0.414273
# [44]	valid_0's binary_logloss: 0.409858
# [45]	valid_0's binary_logloss: 0.405507
# [46]	valid_0's binary_logloss: 0.401225
# [47]	valid_0's binary_logloss: 0.397007
# [48]	valid_0's binary_logloss: 0.392848
# [49]	valid_0's binary_logloss: 0.388751
# [50]	valid_0's binary_logloss: 0.384715
# [51]	valid_0's binary_logloss: 0.38074
# [52]	valid_0's binary_logloss: 0.376824
# [53]	valid_0's binary_logloss: 0.372963
# [54]	valid_0's binary_logloss: 0.36916
# [55]	valid_0's binary_logloss: 0.365411
# [56]	valid_0's binary_logloss: 0.361717
# [57]	valid_0's binary_logloss: 0.358075
# [58]	valid_0's binary_logloss: 0.354486
# [59]	valid_0's binary_logloss: 0.350947
# [60]	valid_0's binary_logloss: 0.34746
# [61]	valid_0's binary_logloss: 0.34402
# [62]	valid_0's binary_logloss: 0.340629
# [63]	valid_0's binary_logloss: 0.337285
# [64]	valid_0's binary_logloss: 0.333992
# [65]	valid_0's binary_logloss: 0.330744
# [66]	valid_0's binary_logloss: 0.32754
# [67]	valid_0's binary_logloss: 0.32438
# [68]	valid_0's binary_logloss: 0.321263
# [69]	valid_0's binary_logloss: 0.318193
# [70]	valid_0's binary_logloss: 0.315162
# [71]	valid_0's binary_logloss: 0.312176
# [72]	valid_0's binary_logloss: 0.309228
# [73]	valid_0's binary_logloss: 0.30632
# [74]	valid_0's binary_logloss: 0.303454
# [75]	valid_0's binary_logloss: 0.300628
# [76]	valid_0's binary_logloss: 0.29784
# [77]	valid_0's binary_logloss: 0.295091
# [78]	valid_0's binary_logloss: 0.292378
# [79]	valid_0's binary_logloss: 0.289703
# [80]	valid_0's binary_logloss: 0.287062
# [81]	valid_0's binary_logloss: 0.284457
# [82]	valid_0's binary_logloss: 0.281888
# [83]	valid_0's binary_logloss: 0.279351
# [84]	valid_0's binary_logloss: 0.276847
# [85]	valid_0's binary_logloss: 0.274377
# [86]	valid_0's binary_logloss: 0.27194
# [87]	valid_0's binary_logloss: 0.269538
# [88]	valid_0's binary_logloss: 0.267169
# [89]	valid_0's binary_logloss: 0.264828
# [90]	valid_0's binary_logloss: 0.262518
# [91]	valid_0's binary_logloss: 0.260239
# [92]	valid_0's binary_logloss: 0.257989
# [93]	valid_0's binary_logloss: 0.25577
# [94]	valid_0's binary_logloss: 0.253581
# [95]	valid_0's binary_logloss: 0.251419
# [96]	valid_0's binary_logloss: 0.249281
# [97]	valid_0's binary_logloss: 0.247173
# [98]	valid_0's binary_logloss: 0.245094
# [99]	valid_0's binary_logloss: 0.243044
# [100]	valid_0's binary_logloss: 0.241018
# [101]	valid_0's binary_logloss: 0.239018
# [102]	valid_0's binary_logloss: 0.237044
# [103]	valid_0's binary_logloss: 0.235098
# [104]	valid_0's binary_logloss: 0.233174
# [105]	valid_0's binary_logloss: 0.231278
# [106]	valid_0's binary_logloss: 0.229404
# [107]	valid_0's binary_logloss: 0.227555
# [108]	valid_0's binary_logloss: 0.225731
# [109]	valid_0's binary_logloss: 0.223929
# [110]	valid_0's binary_logloss: 0.222149
# [111]	valid_0's binary_logloss: 0.220393
# [112]	valid_0's binary_logloss: 0.218659
# [113]	valid_0's binary_logloss: 0.216949
# [114]	valid_0's binary_logloss: 0.215258
# [115]	valid_0's binary_logloss: 0.213591
# [116]	valid_0's binary_logloss: 0.211944
# [117]	valid_0's binary_logloss: 0.210319
# [118]	valid_0's binary_logloss: 0.208713
# [119]	valid_0's binary_logloss: 0.207126
# [120]	valid_0's binary_logloss: 0.205561
# [121]	valid_0's binary_logloss: 0.204013
# [122]	valid_0's binary_logloss: 0.202487
# [123]	valid_0's binary_logloss: 0.200979
# [124]	valid_0's binary_logloss: 0.199492
# [125]	valid_0's binary_logloss: 0.198023
# [126]	valid_0's binary_logloss: 0.196572
# [127]	valid_0's binary_logloss: 0.195139
# [128]	valid_0's binary_logloss: 0.193724
# [129]	valid_0's binary_logloss: 0.192327
# [130]	valid_0's binary_logloss: 0.190946
# [131]	valid_0's binary_logloss: 0.189583
# [132]	valid_0's binary_logloss: 0.188238
# [133]	valid_0's binary_logloss: 0.186909
# [134]	valid_0's binary_logloss: 0.185598
# [135]	valid_0's binary_logloss: 0.184303
# [136]	valid_0's binary_logloss: 0.183023
# [137]	valid_0's binary_logloss: 0.181758
# [138]	valid_0's binary_logloss: 0.180511
# [139]	valid_0's binary_logloss: 0.179278
# [140]	valid_0's binary_logloss: 0.178061
# [141]	valid_0's binary_logloss: 0.176859
# [142]	valid_0's binary_logloss: 0.175673
# [143]	valid_0's binary_logloss: 0.1745
# [144]	valid_0's binary_logloss: 0.173342
# [145]	valid_0's binary_logloss: 0.172197
# [146]	valid_0's binary_logloss: 0.171069
# [147]	valid_0's binary_logloss: 0.169953
# [148]	valid_0's binary_logloss: 0.168842
# [149]	valid_0's binary_logloss: 0.167756
# [150]	valid_0's binary_logloss: 0.166678
# [151]	valid_0's binary_logloss: 0.165618
# [152]	valid_0's binary_logloss: 0.164571
# [153]	valid_0's binary_logloss: 0.163535
# [154]	valid_0's binary_logloss: 0.162513
# [155]	valid_0's binary_logloss: 0.161503
# [156]	valid_0's binary_logloss: 0.160507
# [157]	valid_0's binary_logloss: 0.159523
# [158]	valid_0's binary_logloss: 0.158548
# [159]	valid_0's binary_logloss: 0.157586
# [160]	valid_0's binary_logloss: 0.156637
# [161]	valid_0's binary_logloss: 0.1557
# [162]	valid_0's binary_logloss: 0.154775
# [163]	valid_0's binary_logloss: 0.153862
# [164]	valid_0's binary_logloss: 0.15296
# [165]	valid_0's binary_logloss: 0.152069
# [166]	valid_0's binary_logloss: 0.151188
# [167]	valid_0's binary_logloss: 0.150321
# [168]	valid_0's binary_logloss: 0.149463
# [169]	valid_0's binary_logloss: 0.148615
# [170]	valid_0's binary_logloss: 0.147778
# [171]	valid_0's binary_logloss: 0.146951
# [172]	valid_0's binary_logloss: 0.146134
# [173]	valid_0's binary_logloss: 0.145327
# [174]	valid_0's binary_logloss: 0.14453
# [175]	valid_0's binary_logloss: 0.143742
# [176]	valid_0's binary_logloss: 0.142963
# [177]	valid_0's binary_logloss: 0.142195
# [178]	valid_0's binary_logloss: 0.141436
# [179]	valid_0's binary_logloss: 0.140685
# [180]	valid_0's binary_logloss: 0.139944
# [181]	valid_0's binary_logloss: 0.139212
# [182]	valid_0's binary_logloss: 0.138489
# [183]	valid_0's binary_logloss: 0.137776
# [184]	valid_0's binary_logloss: 0.137074
# [185]	valid_0's binary_logloss: 0.136381
# [186]	valid_0's binary_logloss: 0.135693
# [187]	valid_0's binary_logloss: 0.135014
# [188]	valid_0's binary_logloss: 0.134343
# [189]	valid_0's binary_logloss: 0.133681
# [190]	valid_0's binary_logloss: 0.133028
# [191]	valid_0's binary_logloss: 0.132381
# [192]	valid_0's binary_logloss: 0.131742
# [193]	valid_0's binary_logloss: 0.131112
# [194]	valid_0's binary_logloss: 0.13049
# [195]	valid_0's binary_logloss: 0.129875
# [196]	valid_0's binary_logloss: 0.129271
# [197]	valid_0's binary_logloss: 0.128671
# [198]	valid_0's binary_logloss: 0.128074
# [199]	valid_0's binary_logloss: 0.12749
# [200]	valid_0's binary_logloss: 0.126911
# [201]	valid_0's binary_logloss: 0.12634
# [202]	valid_0's binary_logloss: 0.125776
# [203]	valid_0's binary_logloss: 0.12522
# [204]	valid_0's binary_logloss: 0.124671
# [205]	valid_0's binary_logloss: 0.124129
# [206]	valid_0's binary_logloss: 0.123593
# [207]	valid_0's binary_logloss: 0.123064
# [208]	valid_0's binary_logloss: 0.122542
# [209]	valid_0's binary_logloss: 0.122025
# [210]	valid_0's binary_logloss: 0.121515
# [211]	valid_0's binary_logloss: 0.121012
# [212]	valid_0's binary_logloss: 0.120515
# [213]	valid_0's binary_logloss: 0.120023
# [214]	valid_0's binary_logloss: 0.119539
# [215]	valid_0's binary_logloss: 0.119062
# [216]	valid_0's binary_logloss: 0.118585
# [217]	valid_0's binary_logloss: 0.118118
# [218]	valid_0's binary_logloss: 0.117656
# [219]	valid_0's binary_logloss: 0.117201
# [220]	valid_0's binary_logloss: 0.116752
# [221]	valid_0's binary_logloss: 0.11631
# [222]	valid_0's binary_logloss: 0.115867
# [223]	valid_0's binary_logloss: 0.115434
# [224]	valid_0's binary_logloss: 0.115006
# [225]	valid_0's binary_logloss: 0.114584
# [226]	valid_0's binary_logloss: 0.114165
# [227]	valid_0's binary_logloss: 0.113754
# [228]	valid_0's binary_logloss: 0.113348
# [229]	valid_0's binary_logloss: 0.112943
# [230]	valid_0's binary_logloss: 0.112547
# [231]	valid_0's binary_logloss: 0.112158
# [232]	valid_0's binary_logloss: 0.11177
# [233]	valid_0's binary_logloss: 0.111389
# [234]	valid_0's binary_logloss: 0.11101
# [235]	valid_0's binary_logloss: 0.110636
# [236]	valid_0's binary_logloss: 0.110268
# [237]	valid_0's binary_logloss: 0.109904
# [238]	valid_0's binary_logloss: 0.109544
# [239]	valid_0's binary_logloss: 0.109191
# [240]	valid_0's binary_logloss: 0.108841
# [241]	valid_0's binary_logloss: 0.108495
# [242]	valid_0's binary_logloss: 0.108152
# [243]	valid_0's binary_logloss: 0.107817
# [244]	valid_0's binary_logloss: 0.107485
# [245]	valid_0's binary_logloss: 0.107156
# [246]	valid_0's binary_logloss: 0.106832
# [247]	valid_0's binary_logloss: 0.106512
# [248]	valid_0's binary_logloss: 0.106196
# [249]	valid_0's binary_logloss: 0.105882
# [250]	valid_0's binary_logloss: 0.105574
# [251]	valid_0's binary_logloss: 0.105271
# [252]	valid_0's binary_logloss: 0.104971
# [253]	valid_0's binary_logloss: 0.104673
# [254]	valid_0's binary_logloss: 0.104378
# [255]	valid_0's binary_logloss: 0.104087
# [256]	valid_0's binary_logloss: 0.103802
# [257]	valid_0's binary_logloss: 0.103518
# [258]	valid_0's binary_logloss: 0.103243
# [259]	valid_0's binary_logloss: 0.102966
# [260]	valid_0's binary_logloss: 0.102694
# [261]	valid_0's binary_logloss: 0.102427
# [262]	valid_0's binary_logloss: 0.102163
# [263]	valid_0's binary_logloss: 0.101902
# [264]	valid_0's binary_logloss: 0.101644
# [265]	valid_0's binary_logloss: 0.10139
# [266]	valid_0's binary_logloss: 0.101139
# [267]	valid_0's binary_logloss: 0.100888
# [268]	valid_0's binary_logloss: 0.100645
# [269]	valid_0's binary_logloss: 0.100404
# [270]	valid_0's binary_logloss: 0.100166
# [271]	valid_0's binary_logloss: 0.0999332
# [272]	valid_0's binary_logloss: 0.0997
# [273]	valid_0's binary_logloss: 0.0994708
# [274]	valid_0's binary_logloss: 0.0992435
# [275]	valid_0's binary_logloss: 0.0990183
# [276]	valid_0's binary_logloss: 0.0987945
# [277]	valid_0's binary_logloss: 0.0985771
# [278]	valid_0's binary_logloss: 0.0983599
# [279]	valid_0's binary_logloss: 0.098145
# [280]	valid_0's binary_logloss: 0.0979345
# [281]	valid_0's binary_logloss: 0.0977291
# [282]	valid_0's binary_logloss: 0.0975236
# [283]	valid_0's binary_logloss: 0.0973225
# [284]	valid_0's binary_logloss: 0.0971182
# [285]	valid_0's binary_logloss: 0.096925
# [286]	valid_0's binary_logloss: 0.0967321
# [287]	valid_0's binary_logloss: 0.0965428
# [288]	valid_0's binary_logloss: 0.0963527
# [289]	valid_0's binary_logloss: 0.096166
# [290]	valid_0's binary_logloss: 0.0959813
# [291]	valid_0's binary_logloss: 0.0957984
# [292]	valid_0's binary_logloss: 0.0956156
# [293]	valid_0's binary_logloss: 0.0954378
# [294]	valid_0's binary_logloss: 0.0952638
# [295]	valid_0's binary_logloss: 0.0950923
# [296]	valid_0's binary_logloss: 0.0949217
# [297]	valid_0's binary_logloss: 0.094753
# [298]	valid_0's binary_logloss: 0.0945876
# [299]	valid_0's binary_logloss: 0.0944237
# [300]	valid_0's binary_logloss: 0.0942618
# [301]	valid_0's binary_logloss: 0.0941034
# [302]	valid_0's binary_logloss: 0.0939444
# [303]	valid_0's binary_logloss: 0.0937894
# [304]	valid_0's binary_logloss: 0.0936379
# [305]	valid_0's binary_logloss: 0.0934869
# [306]	valid_0's binary_logloss: 0.0933326
# [307]	valid_0's binary_logloss: 0.0931858
# [308]	valid_0's binary_logloss: 0.0930408
# [309]	valid_0's binary_logloss: 0.0928984
# [310]	valid_0's binary_logloss: 0.0927581
# [311]	valid_0's binary_logloss: 0.0926187
# [312]	valid_0's binary_logloss: 0.0924812
# [313]	valid_0's binary_logloss: 0.0923454
# [314]	valid_0's binary_logloss: 0.0922103
# [315]	valid_0's binary_logloss: 0.0920777
# [316]	valid_0's binary_logloss: 0.0919484
# [317]	valid_0's binary_logloss: 0.0918237
# [318]	valid_0's binary_logloss: 0.0916975
# [319]	valid_0's binary_logloss: 0.0915688
# [320]	valid_0's binary_logloss: 0.0914428
# [321]	valid_0's binary_logloss: 0.0913199
# [322]	valid_0's binary_logloss: 0.0911935
# [323]	valid_0's binary_logloss: 0.0910748
# [324]	valid_0's binary_logloss: 0.090961
# [325]	valid_0's binary_logloss: 0.0908436
# [326]	valid_0's binary_logloss: 0.0907297
# [327]	valid_0's binary_logloss: 0.0906152
# [328]	valid_0's binary_logloss: 0.0905034
# [329]	valid_0's binary_logloss: 0.0903946
# [330]	valid_0's binary_logloss: 0.0902847
# [331]	valid_0's binary_logloss: 0.0901772
# [332]	valid_0's binary_logloss: 0.0900713
# [333]	valid_0's binary_logloss: 0.0899661
# [334]	valid_0's binary_logloss: 0.0898616
# [335]	valid_0's binary_logloss: 0.0897608
# [336]	valid_0's binary_logloss: 0.0896615
# [337]	valid_0's binary_logloss: 0.0895625
# [338]	valid_0's binary_logloss: 0.0894652
# [339]	valid_0's binary_logloss: 0.0893703
# [340]	valid_0's binary_logloss: 0.0892749
# [341]	valid_0's binary_logloss: 0.0891795
# [342]	valid_0's binary_logloss: 0.0890873
# [343]	valid_0's binary_logloss: 0.0889979
# [344]	valid_0's binary_logloss: 0.0889097
# [345]	valid_0's binary_logloss: 0.0888211
# [346]	valid_0's binary_logloss: 0.0887331
# [347]	valid_0's binary_logloss: 0.088647
# [348]	valid_0's binary_logloss: 0.0885623
# [349]	valid_0's binary_logloss: 0.0884784
# [350]	valid_0's binary_logloss: 0.0883956
# [351]	valid_0's binary_logloss: 0.0883128
# [352]	valid_0's binary_logloss: 0.088229
# [353]	valid_0's binary_logloss: 0.0881481
# [354]	valid_0's binary_logloss: 0.0880711
# [355]	valid_0's binary_logloss: 0.0879934
# [356]	valid_0's binary_logloss: 0.0879158
# [357]	valid_0's binary_logloss: 0.0878371
# [358]	valid_0's binary_logloss: 0.0877605
# [359]	valid_0's binary_logloss: 0.0876869
# [360]	valid_0's binary_logloss: 0.0876103
# [361]	valid_0's binary_logloss: 0.0875348
# [362]	valid_0's binary_logloss: 0.0874636
# [363]	valid_0's binary_logloss: 0.0873932
# [364]	valid_0's binary_logloss: 0.0873247
# [365]	valid_0's binary_logloss: 0.0872588
# [366]	valid_0's binary_logloss: 0.0871904
# [367]	valid_0's binary_logloss: 0.0871263
# [368]	valid_0's binary_logloss: 0.0870632
# [369]	valid_0's binary_logloss: 0.0869992
# [370]	valid_0's binary_logloss: 0.0869359
# [371]	valid_0's binary_logloss: 0.0868716
# [372]	valid_0's binary_logloss: 0.0868093
# [373]	valid_0's binary_logloss: 0.0867499
# [374]	valid_0's binary_logloss: 0.0866864
# [375]	valid_0's binary_logloss: 0.0866237
# [376]	valid_0's binary_logloss: 0.0865645
# [377]	valid_0's binary_logloss: 0.0865031
# [378]	valid_0's binary_logloss: 0.0864454
# [379]	valid_0's binary_logloss: 0.0863912
# [380]	valid_0's binary_logloss: 0.0863345
# [381]	valid_0's binary_logloss: 0.0862813
# [382]	valid_0's binary_logloss: 0.0862277
# [383]	valid_0's binary_logloss: 0.0861756
# [384]	valid_0's binary_logloss: 0.086121
# [385]	valid_0's binary_logloss: 0.0860679
# [386]	valid_0's binary_logloss: 0.0860168
# [387]	valid_0's binary_logloss: 0.0859648
# [388]	valid_0's binary_logloss: 0.0859165
# [389]	valid_0's binary_logloss: 0.0858693
# [390]	valid_0's binary_logloss: 0.0858171
# [391]	valid_0's binary_logloss: 0.0857693
# [392]	valid_0's binary_logloss: 0.0857222
# [393]	valid_0's binary_logloss: 0.0856746
# [394]	valid_0's binary_logloss: 0.0856267
# [395]	valid_0's binary_logloss: 0.0855821
# [396]	valid_0's binary_logloss: 0.0855384
# [397]	valid_0's binary_logloss: 0.0854927
# [398]	valid_0's binary_logloss: 0.0854477
# [399]	valid_0's binary_logloss: 0.0854051
# [400]	valid_0's binary_logloss: 0.0853601
# [401]	valid_0's binary_logloss: 0.0853193
# [402]	valid_0's binary_logloss: 0.0852752
# [403]	valid_0's binary_logloss: 0.0852336
# [404]	valid_0's binary_logloss: 0.0851909
# [405]	valid_0's binary_logloss: 0.0851511
# [406]	valid_0's binary_logloss: 0.0851107
# [407]	valid_0's binary_logloss: 0.0850714
# [408]	valid_0's binary_logloss: 0.0850368
# [409]	valid_0's binary_logloss: 0.0850002
# [410]	valid_0's binary_logloss: 0.0849587
# [411]	valid_0's binary_logloss: 0.084924
# [412]	valid_0's binary_logloss: 0.0848877
# [413]	valid_0's binary_logloss: 0.0848506
# [414]	valid_0's binary_logloss: 0.0848145
# [415]	valid_0's binary_logloss: 0.0847793
# [416]	valid_0's binary_logloss: 0.0847449
# [417]	valid_0's binary_logloss: 0.0847089
# [418]	valid_0's binary_logloss: 0.0846736
# [419]	valid_0's binary_logloss: 0.0846391
# [420]	valid_0's binary_logloss: 0.0846071
# [421]	valid_0's binary_logloss: 0.0845725
# [422]	valid_0's binary_logloss: 0.084534
# [423]	valid_0's binary_logloss: 0.0845012
# [424]	valid_0's binary_logloss: 0.0844709
# [425]	valid_0's binary_logloss: 0.0844402
# [426]	valid_0's binary_logloss: 0.0844094
# [427]	valid_0's binary_logloss: 0.0843774
# [428]	valid_0's binary_logloss: 0.0843468
# [429]	valid_0's binary_logloss: 0.0843164
# [430]	valid_0's binary_logloss: 0.0842866
# [431]	valid_0's binary_logloss: 0.0842584
# [432]	valid_0's binary_logloss: 0.0842317
# [433]	valid_0's binary_logloss: 0.0842056
# [434]	valid_0's binary_logloss: 0.0841768
# [435]	valid_0's binary_logloss: 0.0841458
# [436]	valid_0's binary_logloss: 0.0841193
# [437]	valid_0's binary_logloss: 0.0840937
# [438]	valid_0's binary_logloss: 0.084069
# [439]	valid_0's binary_logloss: 0.0840443
# [440]	valid_0's binary_logloss: 0.0840177
# [441]	valid_0's binary_logloss: 0.0839877
# [442]	valid_0's binary_logloss: 0.0839642
# [443]	valid_0's binary_logloss: 0.0839426
# [444]	valid_0's binary_logloss: 0.0839209
# [445]	valid_0's binary_logloss: 0.0838917
# [446]	valid_0's binary_logloss: 0.0838673
# [447]	valid_0's binary_logloss: 0.0838452
# [448]	valid_0's binary_logloss: 0.0838213
# [449]	valid_0's binary_logloss: 0.0837966
# [450]	valid_0's binary_logloss: 0.0837751
# [451]	valid_0's binary_logloss: 0.0837546
# [452]	valid_0's binary_logloss: 0.0837309
# [453]	valid_0's binary_logloss: 0.0837049
# [454]	valid_0's binary_logloss: 0.0836843
# [455]	valid_0's binary_logloss: 0.0836618
# [456]	valid_0's binary_logloss: 0.0836395
# [457]	valid_0's binary_logloss: 0.0836163
# [458]	valid_0's binary_logloss: 0.0835983
# [459]	valid_0's binary_logloss: 0.0835793
# [460]	valid_0's binary_logloss: 0.0835571
# [461]	valid_0's binary_logloss: 0.0835368
# [462]	valid_0's binary_logloss: 0.08352
# [463]	valid_0's binary_logloss: 0.0835005
# [464]	valid_0's binary_logloss: 0.0834822
# [465]	valid_0's binary_logloss: 0.0834611
# [466]	valid_0's binary_logloss: 0.0834384
# [467]	valid_0's binary_logloss: 0.0834213
# [468]	valid_0's binary_logloss: 0.0834031
# [469]	valid_0's binary_logloss: 0.0833859
# [470]	valid_0's binary_logloss: 0.0833662
# [471]	valid_0's binary_logloss: 0.0833485
# [472]	valid_0's binary_logloss: 0.0833335
# [473]	valid_0's binary_logloss: 0.0833147
# [474]	valid_0's binary_logloss: 0.0832985
# [475]	valid_0's binary_logloss: 0.0832798
# [476]	valid_0's binary_logloss: 0.0832592
# [477]	valid_0's binary_logloss: 0.0832425
# [478]	valid_0's binary_logloss: 0.0832261
# [479]	valid_0's binary_logloss: 0.0832098
# [480]	valid_0's binary_logloss: 0.0831941
# [481]	valid_0's binary_logloss: 0.083178
# [482]	valid_0's binary_logloss: 0.0831616
# [483]	valid_0's binary_logloss: 0.0831446
# [484]	valid_0's binary_logloss: 0.0831307
# [485]	valid_0's binary_logloss: 0.0831163
# [486]	valid_0's binary_logloss: 0.0831019
# [487]	valid_0's binary_logloss: 0.0830864
# [488]	valid_0's binary_logloss: 0.0830749
# [489]	valid_0's binary_logloss: 0.08306
# [490]	valid_0's binary_logloss: 0.0830472
# [491]	valid_0's binary_logloss: 0.0830312
# [492]	valid_0's binary_logloss: 0.0830154
# [493]	valid_0's binary_logloss: 0.0830005
# [494]	valid_0's binary_logloss: 0.0829869
# [495]	valid_0's binary_logloss: 0.0829706
# [496]	valid_0's binary_logloss: 0.0829583
# [497]	valid_0's binary_logloss: 0.082944
# [498]	valid_0's binary_logloss: 0.0829341
# [499]	valid_0's binary_logloss: 0.0829246
# [500]	valid_0's binary_logloss: 0.0829116
# [501]	valid_0's binary_logloss: 0.0828955
# [502]	valid_0's binary_logloss: 0.0828845
# [503]	valid_0's binary_logloss: 0.0828731
# [504]	valid_0's binary_logloss: 0.0828589
# [505]	valid_0's binary_logloss: 0.0828464
# [506]	valid_0's binary_logloss: 0.0828333
# [507]	valid_0's binary_logloss: 0.0828193
# [508]	valid_0's binary_logloss: 0.0828081
# [509]	valid_0's binary_logloss: 0.0827962
# [510]	valid_0's binary_logloss: 0.0827823
# [511]	valid_0's binary_logloss: 0.0827676
# [512]	valid_0's binary_logloss: 0.0827587
# [513]	valid_0's binary_logloss: 0.0827479
# [514]	valid_0's binary_logloss: 0.0827347
# [515]	valid_0's binary_logloss: 0.0827201
# [516]	valid_0's binary_logloss: 0.0827075
# [517]	valid_0's binary_logloss: 0.0826975
# [518]	valid_0's binary_logloss: 0.0826905
# [519]	valid_0's binary_logloss: 0.0826799
# [520]	valid_0's binary_logloss: 0.0826697
# [521]	valid_0's binary_logloss: 0.0826582
# [522]	valid_0's binary_logloss: 0.0826476
# [523]	valid_0's binary_logloss: 0.0826397
# [524]	valid_0's binary_logloss: 0.0826294
# [525]	valid_0's binary_logloss: 0.0826206
# [526]	valid_0's binary_logloss: 0.0826108
# [527]	valid_0's binary_logloss: 0.0825982
# [528]	valid_0's binary_logloss: 0.0825917
# [529]	valid_0's binary_logloss: 0.0825818
# [530]	valid_0's binary_logloss: 0.0825718
# [531]	valid_0's binary_logloss: 0.082565
# [532]	valid_0's binary_logloss: 0.0825568
# [533]	valid_0's binary_logloss: 0.0825457
# [534]	valid_0's binary_logloss: 0.0825355
# [535]	valid_0's binary_logloss: 0.0825264
# [536]	valid_0's binary_logloss: 0.0825188
# [537]	valid_0's binary_logloss: 0.0825106
# [538]	valid_0's binary_logloss: 0.0825023
# [539]	valid_0's binary_logloss: 0.0824935
# [540]	valid_0's binary_logloss: 0.0824879
# [541]	valid_0's binary_logloss: 0.0824754
# [542]	valid_0's binary_logloss: 0.0824699
# [543]	valid_0's binary_logloss: 0.0824605
# [544]	valid_0's binary_logloss: 0.0824551
# [545]	valid_0's binary_logloss: 0.0824503
# [546]	valid_0's binary_logloss: 0.0824462
# [547]	valid_0's binary_logloss: 0.0824385
# [548]	valid_0's binary_logloss: 0.0824318
# [549]	valid_0's binary_logloss: 0.0824244
# [550]	valid_0's binary_logloss: 0.0824177
# [551]	valid_0's binary_logloss: 0.0824099
# [552]	valid_0's binary_logloss: 0.082403
# [553]	valid_0's binary_logloss: 0.0823916
# [554]	valid_0's binary_logloss: 0.0823833
# [555]	valid_0's binary_logloss: 0.0823775
# [556]	valid_0's binary_logloss: 0.0823686
# [557]	valid_0's binary_logloss: 0.0823627
# [558]	valid_0's binary_logloss: 0.0823544
# [559]	valid_0's binary_logloss: 0.082348
# [560]	valid_0's binary_logloss: 0.082341
# [561]	valid_0's binary_logloss: 0.0823358
# [562]	valid_0's binary_logloss: 0.0823279
# [563]	valid_0's binary_logloss: 0.0823181
# [564]	valid_0's binary_logloss: 0.0823118
# [565]	valid_0's binary_logloss: 0.0823078
# [566]	valid_0's binary_logloss: 0.0823022
# [567]	valid_0's binary_logloss: 0.0822953
# [568]	valid_0's binary_logloss: 0.0822887
# [569]	valid_0's binary_logloss: 0.0822792
# [570]	valid_0's binary_logloss: 0.0822739
# [571]	valid_0's binary_logloss: 0.0822695
# [572]	valid_0's binary_logloss: 0.0822628
# [573]	valid_0's binary_logloss: 0.0822589
# [574]	valid_0's binary_logloss: 0.0822505
# [575]	valid_0's binary_logloss: 0.0822448
# [576]	valid_0's binary_logloss: 0.0822403
# [577]	valid_0's binary_logloss: 0.0822324
# [578]	valid_0's binary_logloss: 0.082224
# [579]	valid_0's binary_logloss: 0.0822119
# [580]	valid_0's binary_logloss: 0.0822072
# [581]	valid_0's binary_logloss: 0.0821983
# [582]	valid_0's binary_logloss: 0.082193
# [583]	valid_0's binary_logloss: 0.0821885
# [584]	valid_0's binary_logloss: 0.0821824
# [585]	valid_0's binary_logloss: 0.0821785
# [586]	valid_0's binary_logloss: 0.0821722
# [587]	valid_0's binary_logloss: 0.0821672
# [588]	valid_0's binary_logloss: 0.0821633
# [589]	valid_0's binary_logloss: 0.0821603
# [590]	valid_0's binary_logloss: 0.0821564
# [591]	valid_0's binary_logloss: 0.0821495
# [592]	valid_0's binary_logloss: 0.0821453
# [593]	valid_0's binary_logloss: 0.0821391
# [594]	valid_0's binary_logloss: 0.0821342
# [595]	valid_0's binary_logloss: 0.0821319
# [596]	valid_0's binary_logloss: 0.0821277
# [597]	valid_0's binary_logloss: 0.0821241
# [598]	valid_0's binary_logloss: 0.0821179
# [599]	valid_0's binary_logloss: 0.0821108
# [600]	valid_0's binary_logloss: 0.0821069
# [601]	valid_0's binary_logloss: 0.0821009
# [602]	valid_0's binary_logloss: 0.0820945
# [603]	valid_0's binary_logloss: 0.0820924
# [604]	valid_0's binary_logloss: 0.0820895
# [605]	valid_0's binary_logloss: 0.0820846
# [606]	valid_0's binary_logloss: 0.0820748
# [607]	valid_0's binary_logloss: 0.0820675
# [608]	valid_0's binary_logloss: 0.0820604
# [609]	valid_0's binary_logloss: 0.0820563
# [610]	valid_0's binary_logloss: 0.0820511
# [611]	valid_0's binary_logloss: 0.0820448
# [612]	valid_0's binary_logloss: 0.0820392
# [613]	valid_0's binary_logloss: 0.0820342
# [614]	valid_0's binary_logloss: 0.0820311
# [615]	valid_0's binary_logloss: 0.082027
# [616]	valid_0's binary_logloss: 0.0820216
# [617]	valid_0's binary_logloss: 0.082018
# [618]	valid_0's binary_logloss: 0.0820143
# [619]	valid_0's binary_logloss: 0.0820091
# [620]	valid_0's binary_logloss: 0.0820048
# [621]	valid_0's binary_logloss: 0.0820003
# [622]	valid_0's binary_logloss: 0.0819969
# [623]	valid_0's binary_logloss: 0.0819922
# [624]	valid_0's binary_logloss: 0.0819867
# [625]	valid_0's binary_logloss: 0.0819825
# [626]	valid_0's binary_logloss: 0.081979
# [627]	valid_0's binary_logloss: 0.0819719
# [628]	valid_0's binary_logloss: 0.0819696
# [629]	valid_0's binary_logloss: 0.0819665
# [630]	valid_0's binary_logloss: 0.0819633
# [631]	valid_0's binary_logloss: 0.0819559
# [632]	valid_0's binary_logloss: 0.0819491
# [633]	valid_0's binary_logloss: 0.0819428
# [634]	valid_0's binary_logloss: 0.0819374
# [635]	valid_0's binary_logloss: 0.0819321
# [636]	valid_0's binary_logloss: 0.0819312
# [637]	valid_0's binary_logloss: 0.0819264
# [638]	valid_0's binary_logloss: 0.0819246
# [639]	valid_0's binary_logloss: 0.0819217
# [640]	valid_0's binary_logloss: 0.0819172
# [641]	valid_0's binary_logloss: 0.0819138
# [642]	valid_0's binary_logloss: 0.0819085
# [643]	valid_0's binary_logloss: 0.0819056
# [644]	valid_0's binary_logloss: 0.0818982
# [645]	valid_0's binary_logloss: 0.0818971
# [646]	valid_0's binary_logloss: 0.0818926
# [647]	valid_0's binary_logloss: 0.081888
# [648]	valid_0's binary_logloss: 0.0818846
# [649]	valid_0's binary_logloss: 0.0818826
# [650]	valid_0's binary_logloss: 0.0818789
# [651]	valid_0's binary_logloss: 0.0818783
# [652]	valid_0's binary_logloss: 0.0818751
# [653]	valid_0's binary_logloss: 0.0818746
# [654]	valid_0's binary_logloss: 0.0818726
# [655]	valid_0's binary_logloss: 0.0818711
# [656]	valid_0's binary_logloss: 0.0818682
# [657]	valid_0's binary_logloss: 0.0818647
# [658]	valid_0's binary_logloss: 0.0818606
# [659]	valid_0's binary_logloss: 0.081859
# [660]	valid_0's binary_logloss: 0.0818569
# [661]	valid_0's binary_logloss: 0.0818509
# [662]	valid_0's binary_logloss: 0.0818459
# [663]	valid_0's binary_logloss: 0.0818441
# [664]	valid_0's binary_logloss: 0.0818376
# [665]	valid_0's binary_logloss: 0.0818347
# [666]	valid_0's binary_logloss: 0.0818324
# [667]	valid_0's binary_logloss: 0.08183
# [668]	valid_0's binary_logloss: 0.0818297
# [669]	valid_0's binary_logloss: 0.081827
# [670]	valid_0's binary_logloss: 0.0818224
# [671]	valid_0's binary_logloss: 0.0818215
# [672]	valid_0's binary_logloss: 0.0818212
# [673]	valid_0's binary_logloss: 0.0818184
# [674]	valid_0's binary_logloss: 0.0818158
# [675]	valid_0's binary_logloss: 0.0818145
# [676]	valid_0's binary_logloss: 0.0818125
# [677]	valid_0's binary_logloss: 0.0818112
# [678]	valid_0's binary_logloss: 0.0818077
# [679]	valid_0's binary_logloss: 0.0818041
# [680]	valid_0's binary_logloss: 0.0817996
# [681]	valid_0's binary_logloss: 0.0817973
# [682]	valid_0's binary_logloss: 0.0817938
# [683]	valid_0's binary_logloss: 0.0817919
# [684]	valid_0's binary_logloss: 0.0817875
# [685]	valid_0's binary_logloss: 0.0817843
# [686]	valid_0's binary_logloss: 0.0817786
# [687]	valid_0's binary_logloss: 0.0817736
# [688]	valid_0's binary_logloss: 0.0817711
# [689]	valid_0's binary_logloss: 0.0817703
# [690]	valid_0's binary_logloss: 0.0817684
# [691]	valid_0's binary_logloss: 0.0817658
# [692]	valid_0's binary_logloss: 0.0817625
# [693]	valid_0's binary_logloss: 0.0817589
# [694]	valid_0's binary_logloss: 0.0817549
# [695]	valid_0's binary_logloss: 0.0817529
# [696]	valid_0's binary_logloss: 0.0817519
# [697]	valid_0's binary_logloss: 0.081749
# [698]	valid_0's binary_logloss: 0.0817453
# [699]	valid_0's binary_logloss: 0.0817411
# [700]	valid_0's binary_logloss: 0.0817404
# [701]	valid_0's binary_logloss: 0.0817369
# [702]	valid_0's binary_logloss: 0.0817367
# [703]	valid_0's binary_logloss: 0.0817363
# [704]	valid_0's binary_logloss: 0.0817332
# [705]	valid_0's binary_logloss: 0.0817317
# [706]	valid_0's binary_logloss: 0.0817297
# [707]	valid_0's binary_logloss: 0.0817276
# [708]	valid_0's binary_logloss: 0.0817272
# [709]	valid_0's binary_logloss: 0.0817223
# [710]	valid_0's binary_logloss: 0.0817202
# [711]	valid_0's binary_logloss: 0.081717
# [712]	valid_0's binary_logloss: 0.0817131
# [713]	valid_0's binary_logloss: 0.0817096
# [714]	valid_0's binary_logloss: 0.0817088
# [715]	valid_0's binary_logloss: 0.0817085
# [716]	valid_0's binary_logloss: 0.0817093
# [717]	valid_0's binary_logloss: 0.0817089
# [718]	valid_0's binary_logloss: 0.0817072
# [719]	valid_0's binary_logloss: 0.0817031
# [720]	valid_0's binary_logloss: 0.0817009
# [721]	valid_0's binary_logloss: 0.0816993
# [722]	valid_0's binary_logloss: 0.0816971
# [723]	valid_0's binary_logloss: 0.0816949
# [724]	valid_0's binary_logloss: 0.0816944
# [725]	valid_0's binary_logloss: 0.0816956
# [726]	valid_0's binary_logloss: 0.0816933
# [727]	valid_0's binary_logloss: 0.0816928
# [728]	valid_0's binary_logloss: 0.08169
# [729]	valid_0's binary_logloss: 0.081686
# [730]	valid_0's binary_logloss: 0.0816851
# [731]	valid_0's binary_logloss: 0.0816823
# [732]	valid_0's binary_logloss: 0.0816827
# [733]	valid_0's binary_logloss: 0.0816784
# [734]	valid_0's binary_logloss: 0.0816767
# [735]	valid_0's binary_logloss: 0.081674
# [736]	valid_0's binary_logloss: 0.0816737
# [737]	valid_0's binary_logloss: 0.0816726
# [738]	valid_0's binary_logloss: 0.0816707
# [739]	valid_0's binary_logloss: 0.0816682
# [740]	valid_0's binary_logloss: 0.081664
# [741]	valid_0's binary_logloss: 0.0816624
# [742]	valid_0's binary_logloss: 0.0816592
# [743]	valid_0's binary_logloss: 0.0816582
# [744]	valid_0's binary_logloss: 0.0816575
# [745]	valid_0's binary_logloss: 0.0816561
# [746]	valid_0's binary_logloss: 0.0816517
# [747]	valid_0's binary_logloss: 0.0816486
# [748]	valid_0's binary_logloss: 0.0816466
# [749]	valid_0's binary_logloss: 0.0816432
# [750]	valid_0's binary_logloss: 0.0816443
# [751]	valid_0's binary_logloss: 0.0816428
# [752]	valid_0's binary_logloss: 0.0816401
# [753]	valid_0's binary_logloss: 0.0816375
# [754]	valid_0's binary_logloss: 0.0816375
# [755]	valid_0's binary_logloss: 0.0816379
# [756]	valid_0's binary_logloss: 0.0816375
# [757]	valid_0's binary_logloss: 0.0816376
# [758]	valid_0's binary_logloss: 0.0816317
# [759]	valid_0's binary_logloss: 0.0816263
# [760]	valid_0's binary_logloss: 0.0816246
# [761]	valid_0's binary_logloss: 0.0816235
# [762]	valid_0's binary_logloss: 0.0816224
# [763]	valid_0's binary_logloss: 0.0816195
# [764]	valid_0's binary_logloss: 0.0816184
# [765]	valid_0's binary_logloss: 0.0816181
# [766]	valid_0's binary_logloss: 0.0816159
# [767]	valid_0's binary_logloss: 0.0816129
# [768]	valid_0's binary_logloss: 0.0816093
# [769]	valid_0's binary_logloss: 0.0816085
# [770]	valid_0's binary_logloss: 0.0816065
# [771]	valid_0's binary_logloss: 0.0816011
# [772]	valid_0's binary_logloss: 0.0815992
# [773]	valid_0's binary_logloss: 0.0815994
# [774]	valid_0's binary_logloss: 0.0815987
# [775]	valid_0's binary_logloss: 0.0815985
# [776]	valid_0's binary_logloss: 0.081595
# [777]	valid_0's binary_logloss: 0.0815946
# [778]	valid_0's binary_logloss: 0.0815892
# [779]	valid_0's binary_logloss: 0.0815873
# [780]	valid_0's binary_logloss: 0.0815834
# [781]	valid_0's binary_logloss: 0.0815824
# [782]	valid_0's binary_logloss: 0.0815821
# [783]	valid_0's binary_logloss: 0.0815798
# [784]	valid_0's binary_logloss: 0.081577
# [785]	valid_0's binary_logloss: 0.0815756
# [786]	valid_0's binary_logloss: 0.0815737
# [787]	valid_0's binary_logloss: 0.0815727
# [788]	valid_0's binary_logloss: 0.0815716
# [789]	valid_0's binary_logloss: 0.0815716
# [790]	valid_0's binary_logloss: 0.0815691
# [791]	valid_0's binary_logloss: 0.081568
# [792]	valid_0's binary_logloss: 0.0815695
# [793]	valid_0's binary_logloss: 0.0815672
# [794]	valid_0's binary_logloss: 0.0815638
# [795]	valid_0's binary_logloss: 0.0815624
# [796]	valid_0's binary_logloss: 0.0815597
# [797]	valid_0's binary_logloss: 0.081558
# [798]	valid_0's binary_logloss: 0.0815569
# [799]	valid_0's binary_logloss: 0.081556
# [800]	valid_0's binary_logloss: 0.0815546
# [801]	valid_0's binary_logloss: 0.0815513
# [802]	valid_0's binary_logloss: 0.0815499
# [803]	valid_0's binary_logloss: 0.0815489
# [804]	valid_0's binary_logloss: 0.0815491
# [805]	valid_0's binary_logloss: 0.081549
# [806]	valid_0's binary_logloss: 0.0815444
# [807]	valid_0's binary_logloss: 0.0815437
# [808]	valid_0's binary_logloss: 0.0815427
# [809]	valid_0's binary_logloss: 0.0815422
# [810]	valid_0's binary_logloss: 0.081541
# [811]	valid_0's binary_logloss: 0.0815388
# [812]	valid_0's binary_logloss: 0.0815371
# [813]	valid_0's binary_logloss: 0.0815368
# [814]	valid_0's binary_logloss: 0.0815333
# [815]	valid_0's binary_logloss: 0.0815327
# [816]	valid_0's binary_logloss: 0.0815308
# [817]	valid_0's binary_logloss: 0.0815282
# [818]	valid_0's binary_logloss: 0.0815274
# [819]	valid_0's binary_logloss: 0.0815267
# [820]	valid_0's binary_logloss: 0.0815234
# [821]	valid_0's binary_logloss: 0.0815233
# [822]	valid_0's binary_logloss: 0.0815248
# [823]	valid_0's binary_logloss: 0.0815234
# [824]	valid_0's binary_logloss: 0.0815226
# [825]	valid_0's binary_logloss: 0.081521
# [826]	valid_0's binary_logloss: 0.0815212
# [827]	valid_0's binary_logloss: 0.0815206
# [828]	valid_0's binary_logloss: 0.0815201
# [829]	valid_0's binary_logloss: 0.0815199
# [830]	valid_0's binary_logloss: 0.0815197
# [831]	valid_0's binary_logloss: 0.0815174
# [832]	valid_0's binary_logloss: 0.081517
# [833]	valid_0's binary_logloss: 0.0815155
# [834]	valid_0's binary_logloss: 0.0815137
# [835]	valid_0's binary_logloss: 0.0815106
# [836]	valid_0's binary_logloss: 0.0815089
# [837]	valid_0's binary_logloss: 0.0815082
# [838]	valid_0's binary_logloss: 0.0815068
# [839]	valid_0's binary_logloss: 0.0815039
# [840]	valid_0's binary_logloss: 0.0815032
# [841]	valid_0's binary_logloss: 0.0815005
# [842]	valid_0's binary_logloss: 0.0815007
# [843]	valid_0's binary_logloss: 0.0814983
# [844]	valid_0's binary_logloss: 0.0814941
# [845]	valid_0's binary_logloss: 0.0814932
# [846]	valid_0's binary_logloss: 0.0814907
# [847]	valid_0's binary_logloss: 0.0814907
# [848]	valid_0's binary_logloss: 0.0814877
# [849]	valid_0's binary_logloss: 0.0814866
# [850]	valid_0's binary_logloss: 0.0814853
# [851]	valid_0's binary_logloss: 0.0814847
# [852]	valid_0's binary_logloss: 0.0814833
# [853]	valid_0's binary_logloss: 0.0814846
# [854]	valid_0's binary_logloss: 0.0814839
# [855]	valid_0's binary_logloss: 0.0814818
# [856]	valid_0's binary_logloss: 0.0814816
# [857]	valid_0's binary_logloss: 0.0814802
# [858]	valid_0's binary_logloss: 0.0814782
# [859]	valid_0's binary_logloss: 0.0814769
# [860]	valid_0's binary_logloss: 0.0814753
# [861]	valid_0's binary_logloss: 0.0814739
# [862]	valid_0's binary_logloss: 0.0814698
# [863]	valid_0's binary_logloss: 0.081469
# [864]	valid_0's binary_logloss: 0.0814683
# [865]	valid_0's binary_logloss: 0.0814679
# [866]	valid_0's binary_logloss: 0.0814689
# [867]	valid_0's binary_logloss: 0.0814676
# [868]	valid_0's binary_logloss: 0.0814663
# [869]	valid_0's binary_logloss: 0.0814655
# [870]	valid_0's binary_logloss: 0.0814655
# [871]	valid_0's binary_logloss: 0.081466
# [872]	valid_0's binary_logloss: 0.0814642
# [873]	valid_0's binary_logloss: 0.0814646
# [874]	valid_0's binary_logloss: 0.0814624
# [875]	valid_0's binary_logloss: 0.0814595
# [876]	valid_0's binary_logloss: 0.0814589
# [877]	valid_0's binary_logloss: 0.0814587
# [878]	valid_0's binary_logloss: 0.081458
# [879]	valid_0's binary_logloss: 0.0814561
# [880]	valid_0's binary_logloss: 0.0814574
# [881]	valid_0's binary_logloss: 0.0814577
# [882]	valid_0's binary_logloss: 0.0814563
# [883]	valid_0's binary_logloss: 0.0814557
# [884]	valid_0's binary_logloss: 0.0814555
# [885]	valid_0's binary_logloss: 0.0814559
# [886]	valid_0's binary_logloss: 0.0814547
# [887]	valid_0's binary_logloss: 0.0814522
# [888]	valid_0's binary_logloss: 0.0814505
# [889]	valid_0's binary_logloss: 0.0814502
# [890]	valid_0's binary_logloss: 0.0814526
# [891]	valid_0's binary_logloss: 0.0814512
# [892]	valid_0's binary_logloss: 0.0814511
# [893]	valid_0's binary_logloss: 0.0814506
# [894]	valid_0's binary_logloss: 0.0814502
# [895]	valid_0's binary_logloss: 0.0814478
# [896]	valid_0's binary_logloss: 0.0814466
# [897]	valid_0's binary_logloss: 0.0814449
# [898]	valid_0's binary_logloss: 0.0814449
# [899]	valid_0's binary_logloss: 0.0814434
# [900]	valid_0's binary_logloss: 0.081444
# [901]	valid_0's binary_logloss: 0.0814431
# [902]	valid_0's binary_logloss: 0.0814413
# [903]	valid_0's binary_logloss: 0.0814402
# [904]	valid_0's binary_logloss: 0.0814396
# [905]	valid_0's binary_logloss: 0.0814342
# [906]	valid_0's binary_logloss: 0.081433
# [907]	valid_0's binary_logloss: 0.0814316
# [908]	valid_0's binary_logloss: 0.0814318
# [909]	valid_0's binary_logloss: 0.0814309
# [910]	valid_0's binary_logloss: 0.0814299
# [911]	valid_0's binary_logloss: 0.0814266
# [912]	valid_0's binary_logloss: 0.0814254
# [913]	valid_0's binary_logloss: 0.0814254
# [914]	valid_0's binary_logloss: 0.0814259
# [915]	valid_0's binary_logloss: 0.0814254
# [916]	valid_0's binary_logloss: 0.0814277
# [917]	valid_0's binary_logloss: 0.0814284
# [918]	valid_0's binary_logloss: 0.0814284
# [919]	valid_0's binary_logloss: 0.0814255
# [920]	valid_0's binary_logloss: 0.0814246
# [921]	valid_0's binary_logloss: 0.0814221
# [922]	valid_0's binary_logloss: 0.0814191
# [923]	valid_0's binary_logloss: 0.081419
# [924]	valid_0's binary_logloss: 0.0814193
# [925]	valid_0's binary_logloss: 0.0814174
# [926]	valid_0's binary_logloss: 0.0814184
# [927]	valid_0's binary_logloss: 0.0814184
# [928]	valid_0's binary_logloss: 0.081418
# [929]	valid_0's binary_logloss: 0.0814176
# [930]	valid_0's binary_logloss: 0.0814166
# [931]	valid_0's binary_logloss: 0.0814163
# [932]	valid_0's binary_logloss: 0.0814119
# [933]	valid_0's binary_logloss: 0.0814124
# [934]	valid_0's binary_logloss: 0.0814114
# [935]	valid_0's binary_logloss: 0.0814105
# [936]	valid_0's binary_logloss: 0.0814102
# [937]	valid_0's binary_logloss: 0.0814077
# [938]	valid_0's binary_logloss: 0.081408
# [939]	valid_0's binary_logloss: 0.0814058
# [940]	valid_0's binary_logloss: 0.0814065
# [941]	valid_0's binary_logloss: 0.0814065
# [942]	valid_0's binary_logloss: 0.0814048
# [943]	valid_0's binary_logloss: 0.0814045
# [944]	valid_0's binary_logloss: 0.0814051
# [945]	valid_0's binary_logloss: 0.0814031
# [946]	valid_0's binary_logloss: 0.0814021
# [947]	valid_0's binary_logloss: 0.0814015
# [948]	valid_0's binary_logloss: 0.0814022
# [949]	valid_0's binary_logloss: 0.0814034
# [950]	valid_0's binary_logloss: 0.0814032
# [951]	valid_0's binary_logloss: 0.0814029
# [952]	valid_0's binary_logloss: 0.0814015
# [953]	valid_0's binary_logloss: 0.0814001
# [954]	valid_0's binary_logloss: 0.0813996
# [955]	valid_0's binary_logloss: 0.0813991
# [956]	valid_0's binary_logloss: 0.0813992
# [957]	valid_0's binary_logloss: 0.0813999
# [958]	valid_0's binary_logloss: 0.0813987
# [959]	valid_0's binary_logloss: 0.0813984
# [960]	valid_0's binary_logloss: 0.0813983
# [961]	valid_0's binary_logloss: 0.0813977
# [962]	valid_0's binary_logloss: 0.0813967
# [963]	valid_0's binary_logloss: 0.081397
# [964]	valid_0's binary_logloss: 0.081395
# [965]	valid_0's binary_logloss: 0.0813939
# [966]	valid_0's binary_logloss: 0.0813938
# [967]	valid_0's binary_logloss: 0.0813947
# [968]	valid_0's binary_logloss: 0.0813943
# [969]	valid_0's binary_logloss: 0.0813942
# [970]	valid_0's binary_logloss: 0.0813953
# [971]	valid_0's binary_logloss: 0.0813924
# [972]	valid_0's binary_logloss: 0.0813901
# [973]	valid_0's binary_logloss: 0.0813899
# [974]	valid_0's binary_logloss: 0.0813866
# [975]	valid_0's binary_logloss: 0.0813838
# [976]	valid_0's binary_logloss: 0.0813838
# [977]	valid_0's binary_logloss: 0.0813828
# [978]	valid_0's binary_logloss: 0.0813828
# [979]	valid_0's binary_logloss: 0.0813827
# [980]	valid_0's binary_logloss: 0.0813835
# [981]	valid_0's binary_logloss: 0.0813833
# [982]	valid_0's binary_logloss: 0.0813825
# [983]	valid_0's binary_logloss: 0.0813814
# [984]	valid_0's binary_logloss: 0.0813802
# [985]	valid_0's binary_logloss: 0.0813775
# [986]	valid_0's binary_logloss: 0.0813753
# [987]	valid_0's binary_logloss: 0.081376
# [988]	valid_0's binary_logloss: 0.081377
# [989]	valid_0's binary_logloss: 0.0813758
# [990]	valid_0's binary_logloss: 0.0813763
# [991]	valid_0's binary_logloss: 0.0813759
# [992]	valid_0's binary_logloss: 0.0813764
# [993]	valid_0's binary_logloss: 0.0813753
# [994]	valid_0's binary_logloss: 0.0813729
# [995]	valid_0's binary_logloss: 0.0813734
# [996]	valid_0's binary_logloss: 0.0813725
# [997]	valid_0's binary_logloss: 0.0813714
# [998]	valid_0's binary_logloss: 0.0813689
# [999]	valid_0's binary_logloss: 0.0813658
# [1000]	valid_0's binary_logloss: 0.0813658
# [1001]	valid_0's binary_logloss: 0.0813648
# [1002]	valid_0's binary_logloss: 0.0813648
# [1003]	valid_0's binary_logloss: 0.0813651
# [1004]	valid_0's binary_logloss: 0.0813658
# [1005]	valid_0's binary_logloss: 0.0813649
# [1006]	valid_0's binary_logloss: 0.0813621
# [1007]	valid_0's binary_logloss: 0.0813625
# [1008]	valid_0's binary_logloss: 0.0813587
# [1009]	valid_0's binary_logloss: 0.0813574
# [1010]	valid_0's binary_logloss: 0.0813589
# [1011]	valid_0's binary_logloss: 0.0813581
# [1012]	valid_0's binary_logloss: 0.0813577
# [1013]	valid_0's binary_logloss: 0.0813584
# [1014]	valid_0's binary_logloss: 0.081356
# [1015]	valid_0's binary_logloss: 0.0813555
# [1016]	valid_0's binary_logloss: 0.0813563
# [1017]	valid_0's binary_logloss: 0.0813544
# [1018]	valid_0's binary_logloss: 0.0813529
# [1019]	valid_0's binary_logloss: 0.0813538
# [1020]	valid_0's binary_logloss: 0.081352
# [1021]	valid_0's binary_logloss: 0.0813514
# [1022]	valid_0's binary_logloss: 0.0813504
# [1023]	valid_0's binary_logloss: 0.0813468
# [1024]	valid_0's binary_logloss: 0.0813476
# [1025]	valid_0's binary_logloss: 0.0813477
# [1026]	valid_0's binary_logloss: 0.0813478
# [1027]	valid_0's binary_logloss: 0.0813491
# [1028]	valid_0's binary_logloss: 0.0813494
# [1029]	valid_0's binary_logloss: 0.0813502
# [1030]	valid_0's binary_logloss: 0.0813507
# [1031]	valid_0's binary_logloss: 0.0813512
# [1032]	valid_0's binary_logloss: 0.08135
# [1033]	valid_0's binary_logloss: 0.0813493
# [1034]	valid_0's binary_logloss: 0.0813491
# [1035]	valid_0's binary_logloss: 0.0813492
# [1036]	valid_0's binary_logloss: 0.0813491
# [1037]	valid_0's binary_logloss: 0.08135
# [1038]	valid_0's binary_logloss: 0.0813493
# [1039]	valid_0's binary_logloss: 0.0813497
# [1040]	valid_0's binary_logloss: 0.0813501
# [1041]	valid_0's binary_logloss: 0.0813442
# [1042]	valid_0's binary_logloss: 0.0813448
# [1043]	valid_0's binary_logloss: 0.0813449
# [1044]	valid_0's binary_logloss: 0.0813449
# [1045]	valid_0's binary_logloss: 0.0813446
# [1046]	valid_0's binary_logloss: 0.0813435
# [1047]	valid_0's binary_logloss: 0.0813437
# [1048]	valid_0's binary_logloss: 0.0813434
# [1049]	valid_0's binary_logloss: 0.0813436
# [1050]	valid_0's binary_logloss: 0.0813416
# [1051]	valid_0's binary_logloss: 0.0813411
# [1052]	valid_0's binary_logloss: 0.0813412
# [1053]	valid_0's binary_logloss: 0.0813421
# [1054]	valid_0's binary_logloss: 0.0813419
# [1055]	valid_0's binary_logloss: 0.0813416
# [1056]	valid_0's binary_logloss: 0.0813408
# [1057]	valid_0's binary_logloss: 0.0813411
# [1058]	valid_0's binary_logloss: 0.0813421
# [1059]	valid_0's binary_logloss: 0.0813418
# [1060]	valid_0's binary_logloss: 0.0813425
# [1061]	valid_0's binary_logloss: 0.0813426
# [1062]	valid_0's binary_logloss: 0.081342
# [1063]	valid_0's binary_logloss: 0.0813429
# [1064]	valid_0's binary_logloss: 0.0813427
# [1065]	valid_0's binary_logloss: 0.081341
# [1066]	valid_0's binary_logloss: 0.0813405
# [1067]	valid_0's binary_logloss: 0.0813416
# [1068]	valid_0's binary_logloss: 0.0813417
# [1069]	valid_0's binary_logloss: 0.0813424
# [1070]	valid_0's binary_logloss: 0.0813425
# [1071]	valid_0's binary_logloss: 0.0813408
# [1072]	valid_0's binary_logloss: 0.0813404
# [1073]	valid_0's binary_logloss: 0.0813352
# [1074]	valid_0's binary_logloss: 0.0813352
# [1075]	valid_0's binary_logloss: 0.0813352
# [1076]	valid_0's binary_logloss: 0.0813355
# [1077]	valid_0's binary_logloss: 0.0813362
# [1078]	valid_0's binary_logloss: 0.0813365
# [1079]	valid_0's binary_logloss: 0.0813365
# [1080]	valid_0's binary_logloss: 0.0813352
# [1081]	valid_0's binary_logloss: 0.0813331
# [1082]	valid_0's binary_logloss: 0.0813337
# [1083]	valid_0's binary_logloss: 0.0813356
# [1084]	valid_0's binary_logloss: 0.0813355
# [1085]	valid_0's binary_logloss: 0.0813354
# [1086]	valid_0's binary_logloss: 0.0813337
# [1087]	valid_0's binary_logloss: 0.0813305
# [1088]	valid_0's binary_logloss: 0.0813299
# [1089]	valid_0's binary_logloss: 0.0813303
# [1090]	valid_0's binary_logloss: 0.0813313
# [1091]	valid_0's binary_logloss: 0.081331
# [1092]	valid_0's binary_logloss: 0.0813313
# [1093]	valid_0's binary_logloss: 0.0813298
# [1094]	valid_0's binary_logloss: 0.0813291
# [1095]	valid_0's binary_logloss: 0.0813292
# [1096]	valid_0's binary_logloss: 0.0813308
# [1097]	valid_0's binary_logloss: 0.0813308
# [1098]	valid_0's binary_logloss: 0.0813306
# [1099]	valid_0's binary_logloss: 0.0813314
# [1100]	valid_0's binary_logloss: 0.081331
# [1101]	valid_0's binary_logloss: 0.0813302
# [1102]	valid_0's binary_logloss: 0.08133
# [1103]	valid_0's binary_logloss: 0.0813308
# [1104]	valid_0's binary_logloss: 0.0813307
# [1105]	valid_0's binary_logloss: 0.08133
# [1106]	valid_0's binary_logloss: 0.0813297
# [1107]	valid_0's binary_logloss: 0.0813282
# [1108]	valid_0's binary_logloss: 0.0813279
# [1109]	valid_0's binary_logloss: 0.0813294
# [1110]	valid_0's binary_logloss: 0.08133
# [1111]	valid_0's binary_logloss: 0.0813308
# [1112]	valid_0's binary_logloss: 0.0813305
# [1113]	valid_0's binary_logloss: 0.0813316
# [1114]	valid_0's binary_logloss: 0.0813303
# [1115]	valid_0's binary_logloss: 0.0813294
# [1116]	valid_0's binary_logloss: 0.0813293
# [1117]	valid_0's binary_logloss: 0.0813296
# [1118]	valid_0's binary_logloss: 0.0813298
# [1119]	valid_0's binary_logloss: 0.0813292
# [1120]	valid_0's binary_logloss: 0.081329
# [1121]	valid_0's binary_logloss: 0.0813283
# [1122]	valid_0's binary_logloss: 0.0813288
# [1123]	valid_0's binary_logloss: 0.0813285
# [1124]	valid_0's binary_logloss: 0.0813282
# [1125]	valid_0's binary_logloss: 0.0813283
# [1126]	valid_0's binary_logloss: 0.0813298
# [1127]	valid_0's binary_logloss: 0.08133
# [1128]	valid_0's binary_logloss: 0.0813305
# [1129]	valid_0's binary_logloss: 0.0813311
# [1130]	valid_0's binary_logloss: 0.0813323
# [1131]	valid_0's binary_logloss: 0.0813281
# [1132]	valid_0's binary_logloss: 0.0813292
# [1133]	valid_0's binary_logloss: 0.0813299
# [1134]	valid_0's binary_logloss: 0.0813298
# [1135]	valid_0's binary_logloss: 0.0813308
# [1136]	valid_0's binary_logloss: 0.0813308
# [1137]	valid_0's binary_logloss: 0.0813314
# [1138]	valid_0's binary_logloss: 0.0813327
# [1139]	valid_0's binary_logloss: 0.0813307
# [1140]	valid_0's binary_logloss: 0.0813299
# [1141]	valid_0's binary_logloss: 0.0813293
# [1142]	valid_0's binary_logloss: 0.0813286
# [1143]	valid_0's binary_logloss: 0.081327
# [1144]	valid_0's binary_logloss: 0.0813269
# [1145]	valid_0's binary_logloss: 0.0813274
# [1146]	valid_0's binary_logloss: 0.0813273
# [1147]	valid_0's binary_logloss: 0.0813271
# [1148]	valid_0's binary_logloss: 0.0813275
# ...
# [1592]	valid_0's binary_logloss: 0.081212
# [1593]	valid_0's binary_logloss: 0.0812103
# [1594]	valid_0's binary_logloss: 0.0812107
# [1595]	valid_0's binary_logloss: 0.0812106
# [1596]	valid_0's binary_logloss: 0.0812118
# [1597]	valid_0's binary_logloss: 0.0812123
# [1598]	valid_0's binary_logloss: 0.0812104
# [1599]	valid_0's binary_logloss: 0.0812102
# [1600]	valid_0's binary_logloss: 0.0812112
# [1601]	valid_0's binary_logloss: 0.0812107
# [1602]	valid_0's binary_logloss: 0.0812124
# [1603]	valid_0's binary_logloss: 0.0812126
# [1604]	valid_0's binary_logloss: 0.0812118
# [1605]	valid_0's binary_logloss: 0.081213
# [1606]	valid_0's binary_logloss: 0.0812118
# [1607]	valid_0's binary_logloss: 0.0812123
# [1608]	valid_0's binary_logloss: 0.0812105
# [1609]	valid_0's binary_logloss: 0.0812114
# [1610]	valid_0's binary_logloss: 0.0812106
# [1611]	valid_0's binary_logloss: 0.0812081
# [1612]	valid_0's binary_logloss: 0.081208
# [1613]	valid_0's binary_logloss: 0.0812067
# [1614]	valid_0's binary_logloss: 0.0812057
# [1615]	valid_0's binary_logloss: 0.0812028
# [1616]	valid_0's binary_logloss: 0.0812001
# [1617]	valid_0's binary_logloss: 0.0811997
# [1618]	valid_0's binary_logloss: 0.0811997
# [1619]	valid_0's binary_logloss: 0.0811989
# [1620]	valid_0's binary_logloss: 0.0811992
# [1621]	valid_0's binary_logloss: 0.0811998
# [1622]	valid_0's binary_logloss: 0.0812002
# [1623]	valid_0's binary_logloss: 0.0812011
# [1624]	valid_0's binary_logloss: 0.0812014
# [1625]	valid_0's binary_logloss: 0.0812018
# [1626]	valid_0's binary_logloss: 0.0812019
# [1627]	valid_0's binary_logloss: 0.0812011
# [1628]	valid_0's binary_logloss: 0.0811999
# [1629]	valid_0's binary_logloss: 0.0811995
# [1630]	valid_0's binary_logloss: 0.0812
# [1631]	valid_0's binary_logloss: 0.0811986
# [1632]	valid_0's binary_logloss: 0.0811991
# [1633]	valid_0's binary_logloss: 0.0811997
# [1634]	valid_0's binary_logloss: 0.0811994
# [1635]	valid_0's binary_logloss: 0.0812001
# [1636]	valid_0's binary_logloss: 0.0812007
# [1637]	valid_0's binary_logloss: 0.0812011
# [1638]	valid_0's binary_logloss: 0.0812019
# [1639]	valid_0's binary_logloss: 0.0812012
# [1640]	valid_0's binary_logloss: 0.0811993
# [1641]	valid_0's binary_logloss: 0.0811969
# [1642]	valid_0's binary_logloss: 0.0811978
# [1643]	valid_0's binary_logloss: 0.0811954
# [1644]	valid_0's binary_logloss: 0.0811951
# [1645]	valid_0's binary_logloss: 0.0811947
# [1646]	valid_0's binary_logloss: 0.0811948
# [1647]	valid_0's binary_logloss: 0.0811959
# [1648]	valid_0's binary_logloss: 0.0811964
# [1649]	valid_0's binary_logloss: 0.0811973
# [1650]	valid_0's binary_logloss: 0.0811946
# [1651]	valid_0's binary_logloss: 0.0811952
# [1652]	valid_0's binary_logloss: 0.0811939
# [1653]	valid_0's binary_logloss: 0.0811944
# [1654]	valid_0's binary_logloss: 0.0811949
# [1655]	valid_0's binary_logloss: 0.0811937
# [1656]	valid_0's binary_logloss: 0.0811945
# [1657]	valid_0's binary_logloss: 0.0811945
# [1658]	valid_0's binary_logloss: 0.0811955
# [1659]	valid_0's binary_logloss: 0.0811957
# [1660]	valid_0's binary_logloss: 0.0811946
# [1661]	valid_0's binary_logloss: 0.0811933
# [1662]	valid_0's binary_logloss: 0.0811926
# [1663]	valid_0's binary_logloss: 0.0811926
# [1664]	valid_0's binary_logloss: 0.0811929
# [1665]	valid_0's binary_logloss: 0.0811929
# [1666]	valid_0's binary_logloss: 0.0811933
# [1667]	valid_0's binary_logloss: 0.0811947
# [1668]	valid_0's binary_logloss: 0.0811931
# [1669]	valid_0's binary_logloss: 0.081194
# [1670]	valid_0's binary_logloss: 0.0811941
# [1671]	valid_0's binary_logloss: 0.0811936
# [1672]	valid_0's binary_logloss: 0.081193
# [1673]	valid_0's binary_logloss: 0.0811926
# [1674]	valid_0's binary_logloss: 0.0811933
# [1675]	valid_0's binary_logloss: 0.0811916
# [1676]	valid_0's binary_logloss: 0.0811923
# [1677]	valid_0's binary_logloss: 0.0811911
# [1678]	valid_0's binary_logloss: 0.0811922
# [1679]	valid_0's binary_logloss: 0.0811932
# [1680]	valid_0's binary_logloss: 0.0811938
# [1681]	valid_0's binary_logloss: 0.0811937
# [1682]	valid_0's binary_logloss: 0.0811947
# [1683]	valid_0's binary_logloss: 0.0811946
# [1684]	valid_0's binary_logloss: 0.0811926
# [1685]	valid_0's binary_logloss: 0.0811926
# [1686]	valid_0's binary_logloss: 0.081192
# [1687]	valid_0's binary_logloss: 0.0811903
# [1688]	valid_0's binary_logloss: 0.0811883
# [1689]	valid_0's binary_logloss: 0.0811893
# [1690]	valid_0's binary_logloss: 0.0811889
# [1691]	valid_0's binary_logloss: 0.0811886
# [1692]	valid_0's binary_logloss: 0.0811878
# [1693]	valid_0's binary_logloss: 0.0811881
# [1694]	valid_0's binary_logloss: 0.0811877
# [1695]	valid_0's binary_logloss: 0.0811879
# [1696]	valid_0's binary_logloss: 0.0811887
# [1697]	valid_0's binary_logloss: 0.0811862
# [1698]	valid_0's binary_logloss: 0.0811864
# [1699]	valid_0's binary_logloss: 0.0811864
# [1700]	valid_0's binary_logloss: 0.0811841
# [1701]	valid_0's binary_logloss: 0.0811838
# [1702]	valid_0's binary_logloss: 0.0811837
# [1703]	valid_0's binary_logloss: 0.0811829
# [1704]	valid_0's binary_logloss: 0.0811845
# [1705]	valid_0's binary_logloss: 0.0811851
# [1706]	valid_0's binary_logloss: 0.081185
# [1707]	valid_0's binary_logloss: 0.0811842
# [1708]	valid_0's binary_logloss: 0.0811823
# [1709]	valid_0's binary_logloss: 0.0811814
# [1710]	valid_0's binary_logloss: 0.0811811
# [1711]	valid_0's binary_logloss: 0.0811808
# [1712]	valid_0's binary_logloss: 0.0811803
# [1713]	valid_0's binary_logloss: 0.0811814
# [1714]	valid_0's binary_logloss: 0.0811808
# [1715]	valid_0's binary_logloss: 0.0811804
# [1716]	valid_0's binary_logloss: 0.0811807
# [1717]	valid_0's binary_logloss: 0.0811811
# [1718]	valid_0's binary_logloss: 0.0811815
# [1719]	valid_0's binary_logloss: 0.0811819
# [1720]	valid_0's binary_logloss: 0.0811826
# [1721]	valid_0's binary_logloss: 0.0811814
# [1722]	valid_0's binary_logloss: 0.0811815
# [1723]	valid_0's binary_logloss: 0.0811818
# [1724]	valid_0's binary_logloss: 0.0811832
# [1725]	valid_0's binary_logloss: 0.0811836
# [1726]	valid_0's binary_logloss: 0.0811848
# [1727]	valid_0's binary_logloss: 0.0811844
# [1728]	valid_0's binary_logloss: 0.0811845
# [1729]	valid_0's binary_logloss: 0.0811839
# [1730]	valid_0's binary_logloss: 0.081184
# [1731]	valid_0's binary_logloss: 0.0811839
# [1732]	valid_0's binary_logloss: 0.0811812
# [1733]	valid_0's binary_logloss: 0.0811816
# [1734]	valid_0's binary_logloss: 0.0811814
# [1735]	valid_0's binary_logloss: 0.081181
# [1736]	valid_0's binary_logloss: 0.0811815
# [1737]	valid_0's binary_logloss: 0.0811824
# [1738]	valid_0's binary_logloss: 0.0811799
# [1739]	valid_0's binary_logloss: 0.0811808
# [1740]	valid_0's binary_logloss: 0.0811812
# [1741]	valid_0's binary_logloss: 0.0811806
# [1742]	valid_0's binary_logloss: 0.081181
# [1743]	valid_0's binary_logloss: 0.0811801
# [1744]	valid_0's binary_logloss: 0.0811797
# [1745]	valid_0's binary_logloss: 0.0811807
# [1746]	valid_0's binary_logloss: 0.0811816
# [1747]	valid_0's binary_logloss: 0.081183
# [1748]	valid_0's binary_logloss: 0.0811824
# [1749]	valid_0's binary_logloss: 0.0811805
# [1750]	valid_0's binary_logloss: 0.0811816
# [1751]	valid_0's binary_logloss: 0.0811818
# [1752]	valid_0's binary_logloss: 0.081183
# [1753]	valid_0's binary_logloss: 0.0811829
# [1754]	valid_0's binary_logloss: 0.0811813
# [1755]	valid_0's binary_logloss: 0.0811819
# [1756]	valid_0's binary_logloss: 0.0811813
# [1757]	valid_0's binary_logloss: 0.0811811
# [1758]	valid_0's binary_logloss: 0.0811807
# [1759]	valid_0's binary_logloss: 0.081181
# [1760]	valid_0's binary_logloss: 0.0811819
# [1761]	valid_0's binary_logloss: 0.0811805
# [1762]	valid_0's binary_logloss: 0.0811778
# [1763]	valid_0's binary_logloss: 0.0811785
# [1764]	valid_0's binary_logloss: 0.0811783
# [1765]	valid_0's binary_logloss: 0.0811787
# [1766]	valid_0's binary_logloss: 0.0811793
# [1767]	valid_0's binary_logloss: 0.08118
# [1768]	valid_0's binary_logloss: 0.08118
# [1769]	valid_0's binary_logloss: 0.0811805
# [1770]	valid_0's binary_logloss: 0.0811791
# [1771]	valid_0's binary_logloss: 0.0811799
# [1772]	valid_0's binary_logloss: 0.0811801
# [1773]	valid_0's binary_logloss: 0.0811807
# [1774]	valid_0's binary_logloss: 0.0811806
# [1775]	valid_0's binary_logloss: 0.0811825
# [1776]	valid_0's binary_logloss: 0.0811834
# [1777]	valid_0's binary_logloss: 0.0811845
# [1778]	valid_0's binary_logloss: 0.0811851
# [1779]	valid_0's binary_logloss: 0.0811849
# [1780]	valid_0's binary_logloss: 0.0811854
# [1781]	valid_0's binary_logloss: 0.0811853
# [1782]	valid_0's binary_logloss: 0.0811857
# [1783]	valid_0's binary_logloss: 0.0811866
# [1784]	valid_0's binary_logloss: 0.0811866
# [1785]	valid_0's binary_logloss: 0.0811872
# [1786]	valid_0's binary_logloss: 0.081188
# [1787]	valid_0's binary_logloss: 0.081189
# [1788]	valid_0's binary_logloss: 0.0811882
# [1789]	valid_0's binary_logloss: 0.0811874
# [1790]	valid_0's binary_logloss: 0.0811855
# [1791]	valid_0's binary_logloss: 0.081185
# [1792]	valid_0's binary_logloss: 0.0811837
# [1793]	valid_0's binary_logloss: 0.0811853
# [1794]	valid_0's binary_logloss: 0.0811862
# [1795]	valid_0's binary_logloss: 0.0811853
# [1796]	valid_0's binary_logloss: 0.0811842
# [1797]	valid_0's binary_logloss: 0.0811844
# [1798]	valid_0's binary_logloss: 0.0811815
# [1799]	valid_0's binary_logloss: 0.0811812
# [1800]	valid_0's binary_logloss: 0.0811803
# [1801]	valid_0's binary_logloss: 0.081181
# [1802]	valid_0's binary_logloss: 0.0811818
# [1803]	valid_0's binary_logloss: 0.0811818
# [1804]	valid_0's binary_logloss: 0.0811822
# [1805]	valid_0's binary_logloss: 0.0811819
# [1806]	valid_0's binary_logloss: 0.081182
# [1807]	valid_0's binary_logloss: 0.0811814
# [1808]	valid_0's binary_logloss: 0.0811812
# [1809]	valid_0's binary_logloss: 0.0811815
# [1810]	valid_0's binary_logloss: 0.0811814
# [1811]	valid_0's binary_logloss: 0.0811824
# [1812]	valid_0's binary_logloss: 0.081182
# [1813]	valid_0's binary_logloss: 0.0811818
# [1814]	valid_0's binary_logloss: 0.0811821
# [1815]	valid_0's binary_logloss: 0.0811801
# [1816]	valid_0's binary_logloss: 0.0811802
# [1817]	valid_0's binary_logloss: 0.081181
# [1818]	valid_0's binary_logloss: 0.081181
# [1819]	valid_0's binary_logloss: 0.0811817
# [1820]	valid_0's binary_logloss: 0.0811816
# [1821]	valid_0's binary_logloss: 0.0811815
# [1822]	valid_0's binary_logloss: 0.0811819
# [1823]	valid_0's binary_logloss: 0.0811827
# [1824]	valid_0's binary_logloss: 0.0811831
# [1825]	valid_0's binary_logloss: 0.0811832
# [1826]	valid_0's binary_logloss: 0.0811829
# [1827]	valid_0's binary_logloss: 0.0811823
# [1828]	valid_0's binary_logloss: 0.0811825
# [1829]	valid_0's binary_logloss: 0.0811815
# [1830]	valid_0's binary_logloss: 0.081182
# [1831]	valid_0's binary_logloss: 0.081183
# [1832]	valid_0's binary_logloss: 0.0811818
# [1833]	valid_0's binary_logloss: 0.0811827
# [1834]	valid_0's binary_logloss: 0.081183
# [1835]	valid_0's binary_logloss: 0.0811827
# [1836]	valid_0's binary_logloss: 0.0811807
# [1837]	valid_0's binary_logloss: 0.0811815
# [1838]	valid_0's binary_logloss: 0.0811824
# [1839]	valid_0's binary_logloss: 0.0811833
# [1840]	valid_0's binary_logloss: 0.0811832
# [1841]	valid_0's binary_logloss: 0.0811823
# [1842]	valid_0's binary_logloss: 0.0811831
# [1843]	valid_0's binary_logloss: 0.0811842
# [1844]	valid_0's binary_logloss: 0.0811848
# [1845]	valid_0's binary_logloss: 0.081186
# [1846]	valid_0's binary_logloss: 0.0811866
# [1847]	valid_0's binary_logloss: 0.0811859
# [1848]	valid_0's binary_logloss: 0.0811865
# [1849]	valid_0's binary_logloss: 0.0811863
# [1850]	valid_0's binary_logloss: 0.0811858
# [1851]	valid_0's binary_logloss: 0.0811862
# [1852]	valid_0's binary_logloss: 0.0811867
# [1853]	valid_0's binary_logloss: 0.0811864
# [1854]	valid_0's binary_logloss: 0.0811865
# [1855]	valid_0's binary_logloss: 0.0811872
# [1856]	valid_0's binary_logloss: 0.0811878
# [1857]	valid_0's binary_logloss: 0.0811882
# [1858]	valid_0's binary_logloss: 0.0811887
# [1859]	valid_0's binary_logloss: 0.081188
# [1860]	valid_0's binary_logloss: 0.081188
# [1861]	valid_0's binary_logloss: 0.0811883
# [1862]	valid_0's binary_logloss: 0.0811884
# [1863]	valid_0's binary_logloss: 0.0811892
# [1864]	valid_0's binary_logloss: 0.0811899
# [1865]	valid_0's binary_logloss: 0.0811911
# [1866]	valid_0's binary_logloss: 0.08119
# [1867]	valid_0's binary_logloss: 0.0811889
# [1868]	valid_0's binary_logloss: 0.0811888
# [1869]	valid_0's binary_logloss: 0.0811896
# [1870]	valid_0's binary_logloss: 0.08119
# [1871]	valid_0's binary_logloss: 0.0811916
# [1872]	valid_0's binary_logloss: 0.0811924
# [1873]	valid_0's binary_logloss: 0.0811939
# [1874]	valid_0's binary_logloss: 0.0811944
# [1875]	valid_0's binary_logloss: 0.0811946
# [1876]	valid_0's binary_logloss: 0.0811956
# [1877]	valid_0's binary_logloss: 0.0811967
# [1878]	valid_0's binary_logloss: 0.0811949
# [1879]	valid_0's binary_logloss: 0.0811954
# [1880]	valid_0's binary_logloss: 0.0811954
# [1881]	valid_0's binary_logloss: 0.0811956
# [1882]	valid_0's binary_logloss: 0.0811929
# [1883]	valid_0's binary_logloss: 0.0811937
# [1884]	valid_0's binary_logloss: 0.0811937
# [1885]	valid_0's binary_logloss: 0.0811943
# [1886]	valid_0's binary_logloss: 0.0811927
# [1887]	valid_0's binary_logloss: 0.081192
# [1888]	valid_0's binary_logloss: 0.0811909
# [1889]	valid_0's binary_logloss: 0.0811901
# [1890]	valid_0's binary_logloss: 0.0811901
# [1891]	valid_0's binary_logloss: 0.0811913
# [1892]	valid_0's binary_logloss: 0.0811916
# [1893]	valid_0's binary_logloss: 0.0811922
# [1894]	valid_0's binary_logloss: 0.0811924
# [1895]	valid_0's binary_logloss: 0.0811907
# [1896]	valid_0's binary_logloss: 0.0811915
# [1897]	valid_0's binary_logloss: 0.0811916
# [1898]	valid_0's binary_logloss: 0.0811921
# [1899]	valid_0's binary_logloss: 0.0811911
# [1900]	valid_0's binary_logloss: 0.0811917
# [1901]	valid_0's binary_logloss: 0.0811914
# [1902]	valid_0's binary_logloss: 0.0811923
# [1903]	valid_0's binary_logloss: 0.081192
# [1904]	valid_0's binary_logloss: 0.081192
# [1905]	valid_0's binary_logloss: 0.0811932
# [1906]	valid_0's binary_logloss: 0.0811941
# [1907]	valid_0's binary_logloss: 0.0811935
# [1908]	valid_0's binary_logloss: 0.0811925
# [1909]	valid_0's binary_logloss: 0.0811924
# [1910]	valid_0's binary_logloss: 0.0811904
# [1911]	valid_0's binary_logloss: 0.0811908
# [1912]	valid_0's binary_logloss: 0.0811917
# [1913]	valid_0's binary_logloss: 0.0811913
# [1914]	valid_0's binary_logloss: 0.0811917
# [1915]	valid_0's binary_logloss: 0.0811917
# [1916]	valid_0's binary_logloss: 0.0811918
# [1917]	valid_0's binary_logloss: 0.0811909
# [1918]	valid_0's binary_logloss: 0.0811916
# [1919]	valid_0's binary_logloss: 0.0811926
# [1920]	valid_0's binary_logloss: 0.0811912
# [1921]	valid_0's binary_logloss: 0.0811911
# [1922]	valid_0's binary_logloss: 0.0811911
# [1923]	valid_0's binary_logloss: 0.0811928
# [1924]	valid_0's binary_logloss: 0.0811945
# [1925]	valid_0's binary_logloss: 0.0811933
# [1926]	valid_0's binary_logloss: 0.0811939
# [1927]	valid_0's binary_logloss: 0.0811932
# [1928]	valid_0's binary_logloss: 0.0811909
# [1929]	valid_0's binary_logloss: 0.0811912
# [1930]	valid_0's binary_logloss: 0.0811913
# [1931]	valid_0's binary_logloss: 0.0811917
# [1932]	valid_0's binary_logloss: 0.0811924
# [1933]	valid_0's binary_logloss: 0.0811936
# [1934]	valid_0's binary_logloss: 0.0811931
# [1935]	valid_0's binary_logloss: 0.0811934
# [1936]	valid_0's binary_logloss: 0.0811922
# [1937]	valid_0's binary_logloss: 0.0811916
# [1938]	valid_0's binary_logloss: 0.0811915
# [1939]	valid_0's binary_logloss: 0.081192
# [1940]	valid_0's binary_logloss: 0.0811915
# [1941]	valid_0's binary_logloss: 0.0811906
# [1942]	valid_0's binary_logloss: 0.081191
# [1943]	valid_0's binary_logloss: 0.0811901
# [1944]	valid_0's binary_logloss: 0.0811899
# [1945]	valid_0's binary_logloss: 0.0811904
# [1946]	valid_0's binary_logloss: 0.0811916
# [1947]	valid_0's binary_logloss: 0.0811923
# [1948]	valid_0's binary_logloss: 0.081192
# [1949]	valid_0's binary_logloss: 0.0811904
# [1950]	valid_0's binary_logloss: 0.0811905
# [1951]	valid_0's binary_logloss: 0.0811908
# [1952]	valid_0's binary_logloss: 0.0811926
# [1953]	valid_0's binary_logloss: 0.0811933
# [1954]	valid_0's binary_logloss: 0.0811927
# [1955]	valid_0's binary_logloss: 0.0811934
# [1956]	valid_0's binary_logloss: 0.0811933
# [1957]	valid_0's binary_logloss: 0.0811935
# [1958]	valid_0's binary_logloss: 0.0811942
# [1959]	valid_0's binary_logloss: 0.0811948
# [1960]	valid_0's binary_logloss: 0.0811951
# [1961]	valid_0's binary_logloss: 0.0811956
# [1962]	valid_0's binary_logloss: 0.081196
# Early stopping, best iteration is:
# [1762]	valid_0's binary_logloss: 0.0811778

# %%
best_iter = lgb_model.best_iteration_
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)

print(feat_imp)
print(feat_imp.shape)
pred = lgb_model.predict_proba(test[features])[:, 1]
test['pred'] = pred
test['index'] = range(len(test))
print('log loss ', log_loss(test['is_trade'], test['pred']))
# Out:
# shop_score_delivery                           690
# user_pagerank                                 583
# item_id_user_id_prob                          554
# context_id                                    472
# item_price_level                              421
# predict_category_property0                    377
# item_sales_level                              354
# gender_star                                   344
# sale_price                                    337
# hour                                          327
# item_collected_level_item_sales_level_prob    305
# instance_id                                   299
# user_cnt_1_y                                  293
# item_id_trade_count                           287
# item_price_level_user_age_level_prob          283
# user_star_level_user_age_level_prob           280
# user_id                                       278
# shop_score_service                            271
# hour_map_user_id_prob                         266
# item_category_list1                           262
# len_item_property                             260
# item_brand_id_user_id_prob                    247
# user_age_level                                243
# predict_category_property3                    237
# shop_id_item_sales_level_prob                 236
# shop_id_user_id_prob                          222
# predict_category_property1                    209
# shop_cnt_1_y                                  185
# shop_review_positive_rate                     184
# predict_category_property2                    184
#                                              ...
# context_page0_context_id_prob                   0
# context_id_item_brand_id_cnt                    0
# normal_shop                                     0
# context_id_user_gender_id_cnt                   0
# user_id_cvr                                     0
# item_id_cvr                                     0
# shop_id_cvr                                     0
# context_id_user_age_level_cnt                   0
# context_id_count                                0
# context_id_trade_count                          0
# context_id_cvr                                  0
# shop_id_item_id_prob                            0
# context_page0                                   0
# star0                                           0
# context_id_user_gender_id_prob                  0
# occupation0                                     0
# gender0                                         0
# context_id_item_sales_level_cnt                 0
# context_id_item_id_cnt                          0
# hour_map_context_id_prob                        0
# hour_map_context_id_cnt                         0
# context_id_item_collected_level_cnt             0
# context_id_shop_review_num_level_cnt            0
# context_page0_context_id_cnt                    0
# context_id_user_id_cnt                          0
# context_id_shop_id_cnt                          0
# context_id_item_price_level_cnt                 0
# context_id_user_occupation_id_cnt               0
# context_id_item_city_id_cnt                     0
# user_occupation_id_user_id_prob                 0
# Length: 343, dtype: int64
# (343,)
# log loss  0.08117777900734795

# %%
train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]

X = train[features]
y = train[target].values

print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=32,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=best_iter,
    silent = True)

lgb_model = lgb0.fit(X, y)
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)
print(feat_imp)
print(feat_imp.shape)

pred = lgb_model.predict_proba(test[features])[:, 1]
test['predicted_score'] = pred


result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd+test_file, sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
print('\nsaving...')
result.to_csv(wd+output_file, sep=' ', index=False)
# Out:
# Training LGBM model...
# context_id                                    1075
# shop_score_delivery                            936
# instance_id                                    916
# user_pagerank                                  876
# user_id                                        808
# predict_category_property0                     784
# item_id_user_id_prob                           734
# predict_category_property3                     637
# user_star_level_user_age_level_prob            627
# hour                                           609
# predict_category_property1                     554
# gender_star                                    551
# predict_category_property2                     534
# len_item_property                              499
# item_id_trade_count                            486
# item_brand_id_user_id_prob                     476
# shop_score_service                             471
# shop_cnt_1_y                                   469
# item_collected_level_item_sales_level_prob     454
# item_price_level                               451
# item_sales_level                               446
# user_cnt_1_y                                   436
# hour_map_user_id_prob                          427
# item_cnt_1_y                                   421
# predict_category_property4                     403
# shop_cnt_2                                     388
# item_price_level_user_age_level_prob           388
# sale_price                                     385
# item_cnt_2                                     382
# shop_id_item_sales_level_prob                  381
#                                               ...
# user_gender_id                                   2
# context_id_user_gender_id_prob                   1
# context_page0                                    1
# user_occupation_id_user_id_prob                  1
# shop_id_item_id_prob                             0
# user_id_cvr                                      0
# item_id_cvr                                      0
# shop_id_cvr                                      0
# normal_shop                                      0
# context_id_count                                 0
# context_id_trade_count                           0
# context_id_cvr                                   0
# context_page0_context_id_prob                    0
# context_id_shop_review_num_level_cnt             0
# context_id_item_price_level_cnt                  0
# hour_map_context_id_prob                         0
# context_id_item_brand_id_cnt                     0
# context_id_item_id_cnt                           0
# hour_map_context_id_cnt                          0
# context_id_item_city_id_cnt                      0
# context_id_user_age_level_cnt                    0
# context_id_user_occupation_id_cnt                0
# context_id_user_id_cnt                           0
# star0                                            0
# occupation0                                      0
# context_id_item_sales_level_cnt                  0
# context_page0_context_id_cnt                     0
# context_id_user_gender_id_cnt                    0
# context_id_shop_id_cnt                           0
# context_id_item_collected_level_cnt              0
# Length: 343, dtype: int64
# (343,)
#
# saving...

# %%
lgb.plot_importance(lgb_model, figsize=(16, 80))

# %%
from bayes_opt import BayesianOptimization
import numpy as np

test_day = 24
train = data[(data['day'] >= 18) & (data['day'] < test_day)]
test = data[(data['day'] == test_day)]
        
metric = 'binary_logloss'

target = 'is_trade'
drop_list = ['is_trade', 'item_category_list', 'item_property_list', 'predict_category_property', 'realtime', 'context_timestamp', 'Unnamed: 0']
features = [x for x in data.columns if x not in drop_list]

Dtrain = lgb.Dataset(train[features], label = train[target])

def lgb_evaluate(max_depth, colsample_bytree, subsample):

    params = {
        'eta': 0.01,
        'silent': 1,
        'num_boost_round':10000,
        'early_stopping_round':200,
        'n_fold':4,
        'verbose_eval': True,
        'seed': 0
    }

    params['max_depth'] = int(max_depth)
    params['cosample_bytree'] = max(min(colsample_bytree, 1), 0)   
    params['subsample'] = max(min(subsample, 1), 0)

    cv_result = lgb.cv(params, Dtrain, metrics=metric)
    if metric == 'binary_logloss':
        return -np.array(cv_result[list(cv_result.keys())[0]]).max()
    else:
        return np.array(cv_result[list(cv_result.keys())[0]]).max()

lgbBO = BayesianOptimization(lgb_evaluate, {'max_depth': (3, 8),
                                            'colsample_bytree': (0.1, 1),
                                            'subsample': (0.1, 1)})
lgbBO.maximize(init_points=5, n_iter=25)

print('\nbest score:', '{:.6f}'.format(lgbBO.res['max']['max_val']),
      '\nbest parameters:', str({key: '{:.2f}'.format(value) for key, value in lgbBO.res['max']['max_params'].items()}))
# Out:
# Initialization
# ------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   max_depth |   subsample |
#     1 | 02m49s |   -0.09433 |             0.5549 |      3.1574 |      0.7728 |
#     2 | 02m51s |   -0.09408 |             0.7382 |      6.7196 |      0.8821 |
#     3 | 02m50s |   -0.09408 |             0.8337 |      6.1706 |      0.5072 |
#     4 | 02m42s |   -0.09411 |             0.6492 |      5.5913 |      0.3028 |
#     5 | 02m29s |   -0.09421 |             0.3040 |      4.5749 |      0.6776 |
# Bayesian Optimization
# ------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   max_depth |   subsample |
#     6 | 03m00s |   -0.09408 |             0.4186 |      6.1968 |      0.2414 |
#     7 | 02m51s |   -0.09411 |             0.2559 |      5.6212 |      0.3835 |
#     8 | 03m05s |   -0.09411 |             0.6297 |      7.9784 |      0.8377 |
#     9 | 02m38s |   -0.09421 |             0.5589 |      4.6802 |      0.6446 |
#    10 | 03m00s |   -0.09408 |             0.3642 |      6.4804 |      0.3282 |
#    11 | 03m03s |   -0.09411 |             0.9689 |      7.7773 |      0.1823 |
#    12 | 03m05s |   -0.09411 |             0.3622 |      7.5017 |      0.4620 |
#    13 | 02m38s |   -0.09421 |             0.7399 |      4.2970 |      0.1281 |
#    14 | 02m55s |   -0.09408 |             0.8146 |      6.6964 |      0.8482 |
#    15 | 02m52s |   -0.09411 |             0.5379 |      5.5244 |      0.9580 |
#    16 | 28m43s |   -0.09411 |             0.6737 |      5.8664 |      0.7444 |
#    17 | 02m53s |   -0.09411 |             0.9065 |      5.5764 |      0.3036 |
#    18 | 03m02s |   -0.09408 |             0.7290 |      6.5241 |      0.9549 |
#    19 | 03m01s |   -0.09408 |             0.1870 |      6.2689 |      0.3686 |
#    20 | 37m34s |   -0.09411 |             0.9670 |      5.1473 |      0.2330 |
#    21 | 03m46s |   -0.09411 |             0.9730 |      7.7530 |      0.8198 |
#    22 | 68m56s |   -0.09408 |             0.5325 |      6.3441 |      0.9140 |
#    23 | 126m54s |   -0.09421 |             0.6098 |      4.4341 |      0.2518 |
#    24 | 79m19s |   -0.09421 |             0.6603 |      4.5003 |      0.1970 |
#    25 | 17m36s |   -0.09411 |             0.5970 |      5.6775 |      0.1547 |
#    26 | 21m04s |   -0.09408 |             0.9718 |      6.0480 |      0.1530 |
#    27 | 17m27s |   -0.09411 |             0.2888 |      5.0384 |      0.1538 |
#    28 | 21m20s |   -0.09411 |             0.5447 |      7.1177 |      0.4221 |
#    29 | 21m11s |   -0.09411 |             0.3269 |      5.0334 |      0.2411 |
#    30 | 16m58s |   -0.09433 |             0.8843 |      3.2429 |      0.2882 |
#
# best score: -0.094083
# best parameters: {'max_depth': '6.17', 'colsample_bytree': '0.83', 'subsample': '0.51'}

# %% [markdown]
# ## results 32

# %%
import pandas as pd
import lightgbm as lgb

wd = '/Users/ewenwang/Documents/practice_data/conversion_rate/'
test_file = ['round1_ijcai_18_test_a_20180301.txt', 'round1_ijcai_18_test_b_20180418.txt']

file_UISC_union = 'snow_data_UISC_union.txt'
cvr_sm_union = 'cvr_bayesianSM_union.txt'
pagerank_union = 'pagerank_union.txt'

data = pd.read_csv(wd+file_UISC_union, sep=' ')
data = data.merge(pd.read_csv(wd+pagerank_union, sep=' '), on='instance_id', how='left').merge(pd.read_csv(wd+cvr_sm_union, sep=' '), on='instance_id', how='left')

# %%
train= data[(data['day'] >= 18) & (data['day'] <= 23)]
test= data[(data['day'] == 24)]

target = 'is_trade'
drop_list = ['is_trade', 'item_category_list', 'item_property_list', 'predict_category_property', 'realtime', 'context_timestamp', 'Unnamed: 0']
features = [x for x in data.columns if x not in drop_list]

X = train[features]
y = train[target].values
X_tes = test[features]
y_tes = test[target].values

print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=16,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=20000,
    silent = True)

lgb_model = lgb0.fit(X, y, eval_set=[(X_tes, y_tes)], early_stopping_rounds=200)

# %%
from sklearn.metrics import log_loss

best_iter = lgb_model.best_iteration_
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)

print(feat_imp)
print(feat_imp.shape)
pred = lgb_model.predict_proba(test[features])[:, 1]
test['pred'] = pred
test['index'] = range(len(test))
print('log loss ', log_loss(test['is_trade'], test['pred']))

# %%
train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]

X = train[features]
y = train[target].values

print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=32,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=best_iter,
    silent = True)

lgb_model = lgb0.fit(X, y)
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)
print(feat_imp)
print(feat_imp.shape)

pred = lgb_model.predict_proba(test[features])[:, 1]
test['predicted_score'] = pred


result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd+test_file[1], sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)
print('\nsaving...')
result.to_csv(wd+output_file, sep=' ', index=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

lgb.plot_importance(lgb_model, figsize=(16, 80))
