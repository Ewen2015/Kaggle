# %%
import Submission
# %matplotlib inline

# %%
model = Submission.Submission(drop_list=None)
# Out:
# loading...
# 	time spend:  60.09434103965759
# training data merging...
# 	time spend:  17.828909873962402
# train shape:  (1077175, 225)
# saving...
# 	time spend:  271.72502088546753
# Training LGBM model...
# [100]	valid_0's binary_logloss: 0.294355
# [200]	valid_0's binary_logloss: 0.201501
# [300]	valid_0's binary_logloss: 0.177975
# [400]	valid_0's binary_logloss: 0.171831
# [500]	valid_0's binary_logloss: 0.169911
# [600]	valid_0's binary_logloss: 0.169088
# [700]	valid_0's binary_logloss: 0.16863
# [800]	valid_0's binary_logloss: 0.168325
# [900]	valid_0's binary_logloss: 0.168101
# [1000]	valid_0's binary_logloss: 0.16794
# [1100]	valid_0's binary_logloss: 0.167834
# [1200]	valid_0's binary_logloss: 0.167752
# [1300]	valid_0's binary_logloss: 0.167682
# [1400]	valid_0's binary_logloss: 0.167626
# [1500]	valid_0's binary_logloss: 0.167584
# [1600]	valid_0's binary_logloss: 0.167542
# [1700]	valid_0's binary_logloss: 0.167512
# [1800]	valid_0's binary_logloss: 0.167483
# ...
