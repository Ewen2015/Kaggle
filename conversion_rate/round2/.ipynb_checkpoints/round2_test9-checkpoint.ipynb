# %%
import Submission
# %matplotlib inline

# %%
drop_list = ['is_trade', 'instance_id', 'user_id', 'item_id', 'context_id', 'context_page_id', 'shop_id']
valid_hour = 11

model = Submission.Submission(drop_list, valid_hour)
# Out:
# loading...
# 	time spend:  51.123207807540894
# Training LGBM model...
# [100]	valid_0's binary_logloss: 0.294365
# [200]	valid_0's binary_logloss: 0.201562
# [300]	valid_0's binary_logloss: 0.178012
# [400]	valid_0's binary_logloss: 0.171905
# [500]	valid_0's binary_logloss: 0.169965
# [600]	valid_0's binary_logloss: 0.169145
# [700]	valid_0's binary_logloss: 0.16868
# [800]	valid_0's binary_logloss: 0.168379
# [900]	valid_0's binary_logloss: 0.168165
# [1000]	valid_0's binary_logloss: 0.16801
# [1100]	valid_0's binary_logloss: 0.167896
# [1200]	valid_0's binary_logloss: 0.167808
# [1300]	valid_0's binary_logloss: 0.167752
# [1400]	valid_0's binary_logloss: 0.167704
# [1500]	valid_0's binary_logloss: 0.167662
# [1600]	valid_0's binary_logloss: 0.167636
# [1700]	valid_0's binary_logloss: 0.167608
# [1800]	valid_0's binary_logloss: 0.167558
# [1900]	valid_0's binary_logloss: 0.167534
# [2000]	valid_0's binary_logloss: 0.167513
# [2100]	valid_0's binary_logloss: 0.167483
# [2200]	valid_0's binary_logloss: 0.167455
# [2300]	valid_0's binary_logloss: 0.167429
# [2400]	valid_0's binary_logloss: 0.167418
# [2500]	valid_0's binary_logloss: 0.167397
# [2600]	valid_0's binary_logloss: 0.167376
# [2700]	valid_0's binary_logloss: 0.167359
# [2800]	valid_0's binary_logloss: 0.167338
# [2900]	valid_0's binary_logloss: 0.167333
# [3000]	valid_0's binary_logloss: 0.167333
# [3100]	valid_0's binary_logloss: 0.167322
# [3200]	valid_0's binary_logloss: 0.167302
# [3300]	valid_0's binary_logloss: 0.1673
# [3400]	valid_0's binary_logloss: 0.167297
# [3500]	valid_0's binary_logloss: 0.167296
# [3600]	valid_0's binary_logloss: 0.167287
# [3700]	valid_0's binary_logloss: 0.167289
# [3800]	valid_0's binary_logloss: 0.167285
# [3900]	valid_0's binary_logloss: 0.167278
# [4000]	valid_0's binary_logloss: 0.16726
# [4100]	valid_0's binary_logloss: 0.16725
# [4200]	valid_0's binary_logloss: 0.167252
# [4300]	valid_0's binary_logloss: 0.167258
# 	time spend:  1131.2273683547974
# best_iter:  4104
# best_score:  defaultdict(<class 'dict'>, {'valid_0': {'binary_logloss': 0.1672486155740826}})
# Training LGBM model...
# 	time spend:  1618.5491449832916
# loading...
# 	time spend:  96.74365186691284
# predicting...
# 	time spend:  412.09819316864014
#
# saving...
# 	time spend:  4.841608047485352
# plotting...
