# %%
import time
import pandas as pd 
import lightgbm as lgb
from sklearn.model_selection import train_test_split

import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
wd = ['/Users/ewenwang/Documents/practice_data/conversion_rate/', '/Users/ewenwang/Documents/GitHub/Kaggle/conversion_rate/round2/']

test_file = ['round2_ijcai_18_test_a_20180425.txt']

uisc_file = ['round2_uisc_train_7.txt', 'round2_uisc_test_a.txt']
mat_file = ['round2_mat_train_7.txt' ,'round2_mat_test_a.txt']
match_file = ['round2_match_train_7.txt', 'round2_match_test_a.txt']
page_file = ['round2_page_data_a.txt']

print('loading...')
t0=time.time()
train = pd.read_csv(wd[0]+uisc_file[0], sep=' ')
test = pd.read_csv(wd[0]+uisc_file[1], sep=' ')

pagerank = pd.read_csv(wd[0]+page_file[0], sep=' ')
print('\ttime spend: ', time.time()-t0)

print('training data merging...')
t0=time.time()
train = (train.merge(pd.read_csv(wd[0]+mat_file[0], sep=' '), on='instance_id', how='left')
                 .merge(pd.read_csv(wd[0]+match_file[0], sep=' '), on='instance_id', how='left')
                 .merge(pagerank, on='instance_id', how='left'))
print('\ttime spend: ', time.time()-t0)

print('test data merging...')
t0=time.time()
test = (test.merge(pd.read_csv(wd[0]+mat_file[1], sep=' '), on='instance_id', how='left')
               .merge(pd.read_csv(wd[0]+match_file[1], sep=' '), on='instance_id', how='left')
               .merge(pagerank, on='instance_id', how='left'))
print('\ttime spend: ', time.time()-t0)
# Out:
# loading...
# 	time spend:  60.810832023620605
# training data merging...
# 	time spend:  148.30159497261047
# test data merging...
# 	time spend:  63.17984890937805

# %%
train.to_csv(wd[0]+'round2_union_train_7.txt', index=False, sep=' ')
test.to_csv(wd[0]+'round2_union_test_a.txt', index=False, sep=' ')

# %%
wd = ['/Users/ewenwang/Documents/practice_data/conversion_rate/', '/Users/ewenwang/Documents/GitHub/Kaggle/conversion_rate/round2/']

union_file = ['round2_union_train_7.txt', 'round2_union_test_a.txt']

train = pd.read_csv(wd[0]+'round2_union_train_7.txt', sep=' ')
test = pd.read_csv(wd[0]+'round2_union_test_a.txt', sep=' ')

# %%
print(test.shape)
print(train.shape)
# Out:
# (519888, 310)
# (1077175, 310)

# %%
for i in train.columns:
    print(i)
# Out:
# context_id_x
# context_page_id_x
# instance_id
# is_trade_x
# item_brand_id_x
# item_city_id_x
# item_collected_level_x
# item_id_x
# item_price_level_x
# item_pv_level_x
# item_sales_level_x
# realtime
# shop_id_x
# shop_review_num_level_x
# shop_review_positive_rate_x
# shop_score_delivery_x
# shop_score_description_x
# shop_score_service_x
# shop_star_level_x
# user_age_level_x
# user_gender_id_x
# user_id_x
# user_occupation_id_x
# user_star_level_x
# hour
# minute
# minute_of_day
# user_id_cnt
# item_id_user_id_cnt
# item_brand_id_user_id_cnt
# item_city_id_user_id_cnt
# item_price_level_user_id_cnt
# item_sales_level_user_id_cnt
# item_collected_level_user_id_cnt
# item_pv_level_user_id_cnt
# shop_id_user_id_cnt
# shop_review_num_level_user_id_cnt
# shop_star_level_user_id_cnt
# context_id_user_id_cnt
# hour_user_id_cnt
# context_page_id_user_id_cnt
# user_gender_id_cnt
# item_id_user_gender_id_cnt
# item_brand_id_user_gender_id_cnt
# item_city_id_user_gender_id_cnt
# item_price_level_user_gender_id_cnt
# item_sales_level_user_gender_id_cnt
# item_collected_level_user_gender_id_cnt
# item_pv_level_user_gender_id_cnt
# shop_id_user_gender_id_cnt
# shop_review_num_level_user_gender_id_cnt
# shop_star_level_user_gender_id_cnt
# context_id_user_gender_id_cnt
# hour_user_gender_id_cnt
# context_page_id_user_gender_id_cnt
# user_age_level_cnt
# item_id_user_age_level_cnt
# item_brand_id_user_age_level_cnt
# item_city_id_user_age_level_cnt
# item_price_level_user_age_level_cnt
# item_sales_level_user_age_level_cnt
# item_collected_level_user_age_level_cnt
# item_pv_level_user_age_level_cnt
# shop_id_user_age_level_cnt
# shop_review_num_level_user_age_level_cnt
# shop_star_level_user_age_level_cnt
# context_id_user_age_level_cnt
# hour_user_age_level_cnt
# context_page_id_user_age_level_cnt
# user_occupation_id_cnt
# item_id_user_occupation_id_cnt
# item_brand_id_user_occupation_id_cnt
# item_city_id_user_occupation_id_cnt
# item_price_level_user_occupation_id_cnt
# item_sales_level_user_occupation_id_cnt
# item_collected_level_user_occupation_id_cnt
# item_pv_level_user_occupation_id_cnt
# shop_id_user_occupation_id_cnt
# shop_review_num_level_user_occupation_id_cnt
# shop_star_level_user_occupation_id_cnt
# context_id_user_occupation_id_cnt
# hour_user_occupation_id_cnt
# context_page_id_user_occupation_id_cnt
# item_id_cnt
# user_id_item_id_cnt
# user_gender_id_item_id_cnt
# user_age_level_item_id_cnt
# user_occupation_id_item_id_cnt
# user_star_level_item_id_cnt
# shop_id_item_id_cnt
# shop_review_num_level_item_id_cnt
# shop_star_level_item_id_cnt
# context_id_item_id_cnt
# hour_item_id_cnt
# context_page_id_item_id_cnt
# item_brand_id_cnt
# user_id_item_brand_id_cnt
# user_gender_id_item_brand_id_cnt
# user_age_level_item_brand_id_cnt
# user_occupation_id_item_brand_id_cnt
# user_star_level_item_brand_id_cnt
# shop_id_item_brand_id_cnt
# shop_review_num_level_item_brand_id_cnt
# shop_star_level_item_brand_id_cnt
# context_id_item_brand_id_cnt
# hour_item_brand_id_cnt
# context_page_id_item_brand_id_cnt
# item_city_id_cnt
# user_id_item_city_id_cnt
# user_gender_id_item_city_id_cnt
# user_age_level_item_city_id_cnt
# user_occupation_id_item_city_id_cnt
# user_star_level_item_city_id_cnt
# shop_id_item_city_id_cnt
# shop_review_num_level_item_city_id_cnt
# shop_star_level_item_city_id_cnt
# context_id_item_city_id_cnt
# hour_item_city_id_cnt
# context_page_id_item_city_id_cnt
# item_price_level_cnt
# user_id_item_price_level_cnt
# user_gender_id_item_price_level_cnt
# user_age_level_item_price_level_cnt
# user_occupation_id_item_price_level_cnt
# user_star_level_item_price_level_cnt
# shop_id_item_price_level_cnt
# shop_review_num_level_item_price_level_cnt
# shop_star_level_item_price_level_cnt
# context_id_item_price_level_cnt
# hour_item_price_level_cnt
# context_page_id_item_price_level_cnt
# item_sales_level_cnt
# user_id_item_sales_level_cnt
# user_gender_id_item_sales_level_cnt
# user_age_level_item_sales_level_cnt
# user_occupation_id_item_sales_level_cnt
# user_star_level_item_sales_level_cnt
# shop_id_item_sales_level_cnt
# shop_review_num_level_item_sales_level_cnt
# shop_star_level_item_sales_level_cnt
# context_id_item_sales_level_cnt
# hour_item_sales_level_cnt
# context_page_id_item_sales_level_cnt
# item_collected_level_cnt
# user_id_item_collected_level_cnt
# user_gender_id_item_collected_level_cnt
# user_age_level_item_collected_level_cnt
# user_occupation_id_item_collected_level_cnt
# user_star_level_item_collected_level_cnt
# shop_id_item_collected_level_cnt
# shop_review_num_level_item_collected_level_cnt
# shop_star_level_item_collected_level_cnt
# context_id_item_collected_level_cnt
# hour_item_collected_level_cnt
# context_page_id_item_collected_level_cnt
# shop_id_cnt
# user_id_shop_id_cnt
# user_gender_id_shop_id_cnt
# user_age_level_shop_id_cnt
# user_occupation_id_shop_id_cnt
# user_star_level_shop_id_cnt
# item_id_shop_id_cnt
# item_brand_id_shop_id_cnt
# item_city_id_shop_id_cnt
# item_price_level_shop_id_cnt
# item_sales_level_shop_id_cnt
# item_collected_level_shop_id_cnt
# item_pv_level_shop_id_cnt
# shop_review_num_level_cnt
# user_id_shop_review_num_level_cnt
# user_gender_id_shop_review_num_level_cnt
# user_age_level_shop_review_num_level_cnt
# user_occupation_id_shop_review_num_level_cnt
# user_star_level_shop_review_num_level_cnt
# item_id_shop_review_num_level_cnt
# item_brand_id_shop_review_num_level_cnt
# item_city_id_shop_review_num_level_cnt
# item_price_level_shop_review_num_level_cnt
# item_sales_level_shop_review_num_level_cnt
# item_collected_level_shop_review_num_level_cnt
# item_pv_level_shop_review_num_level_cnt
# item_id_y
# item_category_list
# item_property_list
# item_brand_id_y
# item_city_id_y
# item_price_level_y
# item_sales_level_y
# item_collected_level_y
# item_pv_level_y
# user_id_y
# user_gender_id_y
# user_age_level_y
# user_occupation_id_y
# user_star_level_y
# context_id_y
# context_timestamp
# context_page_id_y
# predict_category_property
# shop_id_y
# shop_review_num_level_y
# shop_review_positive_rate_y
# shop_star_level_y
# shop_score_service_y
# shop_score_delivery_y
# shop_score_description_y
# is_trade_y
# context_realtime
# context_day
# context_hour
# shopping_hour
# num_category
# item_category_1
# item_category_2
# user_instance_cnt
# user_item_cnt
# user_item_avg
# user_price_avg
# user_price_sd
# user_price_max
# user_price_min
# user_item_pv_avg
# user_item_pv_sd
# user_item_pv_max
# user_item_pv_min
# user_item_price_avg
# user_item_price_sd
# user_item_price_max
# user_item_price_min
# user_item_sales_avg
# user_item_sales_sd
# user_item_sales_max
# user_item_sales_min
# user_item_collected_avg
# user_item_collected_sd
# user_item_collected_max
# user_item_collected_min
# user_context_cnt
# user_context_page_cnt
# user_shop_cnt
# user_shop_review_num_avg
# user_shop_review_num_sd
# user_shop_review_num_max
# user_shop_review_num_min
# user_shop_review_positive_rate_avg
# user_shop_review_positive_rate_sd
# user_shop_review_positive_rate_max
# user_shop_review_positive_rate_min
# user_shop_star_avg
# user_shop_star_sd
# user_shop_score_service_avg
# user_shop_score_service_sd
# user_shop_score_service_max
# user_shop_score_service_min
# user_shop_score_delivery_avg
# user_shop_score_delivery_sd
# user_shop_score_delivery_max
# user_shop_score_delivery_min
# user_shop_score_description_avg
# user_shop_score_description_sd
# user_shop_score_description_max
# user_shop_score_description_min
# item_instance_cnt
# item_user_cnt
# item_user_avg
# item_user_gender_avg
# item_user_age_avg
# item_user_oppcupation_avg
# item_user_star_avg
# item_is_trade_count
# user_instance_past_cnt
# user_item_past_cnt
# user_item_past_avg
# user_shopping_hour_avg
# user_shopping_hour_sd
# user_shopping_hour_max
# user_shopping_hour_min
# user_price_past_avg
# user_price_past_sd
# user_price_past_max
# user_price_past_min
# user_item_pv_past_avg
# user_item_pv_past_sd
# user_item_pv_past_max
# user_item_pv_past_min
# user_item_price_past_avg
# user_item_price_past_sd
# user_item_price_past_max
# user_item_price_past_min
# user_item_sales_past_avg
# user_item_sales_past_sd
# user_item_sales_past_max
# user_item_sales_past_min
# user_item_collected_past_avg
# user_item_collected_past_sd
# user_item_collected_past_max
# user_item_collected_past_min
# item_instance_past_cnt
# item_user_past_cnt
# item_user_past_avg
# item_is_trade_past_count
# item_past_cvr
# item_user_gender_past_avg
# item_user_age_past_avg
# item_user_oppcupation_past_avg
# item_user_star_past_avg
# match_cat
# match_ct
# user_pagerank
# item_pagerank

# %%
train_, valid_ = train_test_split(train, test_size=0.2, random_state=0)

# %%
target = 'is_trade_x'
drop_list = ['is_trade_x', 'is_trade_y', 'instance_id',
             'item_category_list', 'item_property_list', 'predict_category_property', 
             'context_realtime', 'context_hour', 'context_day', 'realtime']
features = [x for x in train.columns if x not in drop_list]

# %%
print(train_.shape)
print(valid_.shape)
# Out:
# (861740, 310)
# (215435, 310)

# %%
train_.head()
# Out:
#         context_id_x  context_page_id_x          instance_id  is_trade_x  \
# 54674         984116               4006  8556589603135915299         0.0
# 653543        927397               4001  1146992214670236805         0.0
# 110070        341412               4014  8024119818865797410         0.0
# 631265       1438277               4001  6879310268537982315         0.0
# 441233          6335               4001  4667095300417810211         0.0
#
#         item_brand_id_x  item_city_id_x  item_collected_level_x  item_id_x  \
# 54674              4237              75                      12      28329
# 653543               27              20                      15       1364
# 110070                0              20                      12      15741
# 631265             4506              13                      11      13998
# 441233             7716             108                      13      26989
#
#         item_price_level_x  item_pv_level_x      ...        \
# 54674                    8               17      ...
# 653543                   8               19      ...
# 110070                   2               17      ...
# 631265                   7               19      ...
# 441233                   7               19      ...
#
#         item_is_trade_past_count item_past_cvr  item_user_gender_past_avg  \
# 54674                      848.0           1.0                   0.215802
# 653543                    7198.0           1.0                   0.223673
# 110070                     755.0           1.0                   0.231788
# 631265                    1742.0           1.0                   0.172790
# 441233                    3912.0           1.0                   0.186861
#
#         item_user_age_past_avg  item_user_oppcupation_past_avg  \
# 54674              1003.837264                     2003.913915
# 653543             1000.811892                     1998.525146
# 110070             1003.598675                     2003.936424
# 631265              999.198622                     1993.619977
# 441233             1002.579499                     2001.083333
#
#         item_user_star_past_avg  match_cat  match_ct  user_pagerank  \
# 54674               3004.797170        0.0       2.0   1.601509e-06
# 653543              2995.394276        0.0       2.0   4.606031e-07
# 110070              3004.421192        0.0       2.0   7.143044e-07
# 631265              2987.914466        0.0       2.0   5.548944e-07
# 441233              3002.734407        NaN       NaN   5.753924e-07
#
#         item_pagerank
# 54674        0.000088
# 653543       0.000382
# 110070       0.000037
# 631265       0.000189
# 441233       0.000670
#
# [5 rows x 310 columns]

# %%
X = train_[features]
y = train_[target]
X_tes = valid_[features]
y_tes = valid_[target]

# %%
print('Training LGBM model...')
t0=time.time()
lgb_1 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=16,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=20000,
    silent = True)

lgb_model_1 = lgb_1.fit(X, y, eval_set=[(X_tes, y_tes)], early_stopping_rounds=200, verbose=False, callbacks=[lgb.print_evaluation(100)])
print('\ttime spend: ', time.time()-t0)

best_iter = lgb_model_1.best_iteration_
best_score = lgb_model_1.best_score_

print('best_iter: ', best_iter, '\nbest_score: ', best_score)
# Out:
# Training LGBM model...
# [100]	valid_0's binary_logloss: 0.297726
# [200]	valid_0's binary_logloss: 0.207298
# [300]	valid_0's binary_logloss: 0.18531
# [400]	valid_0's binary_logloss: 0.180069
# [500]	valid_0's binary_logloss: 0.178443
# [600]	valid_0's binary_logloss: 0.177692
# [700]	valid_0's binary_logloss: 0.177231
# [800]	valid_0's binary_logloss: 0.176913
# [900]	valid_0's binary_logloss: 0.176684
# [1000]	valid_0's binary_logloss: 0.176498
# [1100]	valid_0's binary_logloss: 0.176365
# [1200]	valid_0's binary_logloss: 0.176262
# [1300]	valid_0's binary_logloss: 0.17618
# [1400]	valid_0's binary_logloss: 0.176114
# [1500]	valid_0's binary_logloss: 0.176049
# [1600]	valid_0's binary_logloss: 0.176
# [1700]	valid_0's binary_logloss: 0.175966
# [1800]	valid_0's binary_logloss: 0.175927
# [1900]	valid_0's binary_logloss: 0.175888
# [2000]	valid_0's binary_logloss: 0.175862
# [2100]	valid_0's binary_logloss: 0.175832
# [2200]	valid_0's binary_logloss: 0.175808
# [2300]	valid_0's binary_logloss: 0.17578
# [2400]	valid_0's binary_logloss: 0.175754
# [2500]	valid_0's binary_logloss: 0.175725
# [2600]	valid_0's binary_logloss: 0.175702
# [2700]	valid_0's binary_logloss: 0.175684
# [2800]	valid_0's binary_logloss: 0.175661
# [2900]	valid_0's binary_logloss: 0.175643
# [3000]	valid_0's binary_logloss: 0.175627
# [3100]	valid_0's binary_logloss: 0.17561
# [3200]	valid_0's binary_logloss: 0.175597
# [3300]	valid_0's binary_logloss: 0.175585
# [3400]	valid_0's binary_logloss: 0.175574
# [3500]	valid_0's binary_logloss: 0.175556
# [3600]	valid_0's binary_logloss: 0.175539
# [3700]	valid_0's binary_logloss: 0.175519
# [3800]	valid_0's binary_logloss: 0.175505
# [3900]	valid_0's binary_logloss: 0.175497
# [4000]	valid_0's binary_logloss: 0.175479
# [4100]	valid_0's binary_logloss: 0.175459
# [4200]	valid_0's binary_logloss: 0.175448
# [4300]	valid_0's binary_logloss: 0.175441
# [4400]	valid_0's binary_logloss: 0.175436
# [4500]	valid_0's binary_logloss: 0.175427
# [4600]	valid_0's binary_logloss: 0.175418
# [4700]	valid_0's binary_logloss: 0.175415
# [4800]	valid_0's binary_logloss: 0.175406
# [4900]	valid_0's binary_logloss: 0.175394
# [5000]	valid_0's binary_logloss: 0.17539
# [5100]	valid_0's binary_logloss: 0.175384
# [5200]	valid_0's binary_logloss: 0.175376
# [5300]	valid_0's binary_logloss: 0.175372
# [5400]	valid_0's binary_logloss: 0.175361
# [5500]	valid_0's binary_logloss: 0.175359
# [5600]	valid_0's binary_logloss: 0.175357
# [5700]	valid_0's binary_logloss: 0.175353
# [5800]	valid_0's binary_logloss: 0.175347
# [5900]	valid_0's binary_logloss: 0.175339
# [6000]	valid_0's binary_logloss: 0.175336
# [6100]	valid_0's binary_logloss: 0.17533
# [6200]	valid_0's binary_logloss: 0.175325
# [6300]	valid_0's binary_logloss: 0.175317
# [6400]	valid_0's binary_logloss: 0.17531
# [6500]	valid_0's binary_logloss: 0.175293
# [6600]	valid_0's binary_logloss: 0.175289
# [6700]	valid_0's binary_logloss: 0.175283
# [6800]	valid_0's binary_logloss: 0.175277
# [6900]	valid_0's binary_logloss: 0.175273
# [7000]	valid_0's binary_logloss: 0.175264
# [7100]	valid_0's binary_logloss: 0.175261
# [7200]	valid_0's binary_logloss: 0.175262
# 	time spend:  2697.3968250751495

# %%
best_iter = 7025

X_2 = train[features]
y_2 = train[target].values

print('Training LGBM model...')
t0=time.time()
lgb_2 = lgb.LGBMClassifier(
    objective='binary',
    metric='binary_logloss',
    num_leaves=32,
    depth=4,
    learning_rate=0.01,
    seed=2018,
    colsample_bytree=0.6,
    subsample=0.9,
    n_estimators=best_iter,
    silent = True)

lgb_model_2 = lgb_2.fit(X_2, y_2)
print('\ttime spend: ', time.time()-t0)
# Out:
# Training LGBM model...
# 	time spend:  19400.498589992523

# %%
test_file = ['round2_ijcai_18_test_a_20180425.txt']

print('predicting...')
t0=time.time()
pred = lgb_model_2.predict_proba(test[features])[:, 1]
print('\ttime spend: ', time.time()-t0)

test['predicted_score'] = pred

result = test[['instance_id', 'predicted_score']]
result = pd.DataFrame(pd.read_csv(wd[0]+test_file[0], sep=' ')['instance_id']).merge(result, on='instance_id', how='left').fillna(0)

print('\nsaving...')
t0=time.time()
result.to_csv(wd[0]+'results.txt', sep=' ', index=False)
print('\ttime spend: ', time.time()-t0)
# Out:
# saving...
# 	time spend:  2.4094960689544678
# plotting...

# %%
print('plotting...')
lgb.plot_importance(lgb_model_2, figsize=(12, 55))
# Out:
# plotting...
