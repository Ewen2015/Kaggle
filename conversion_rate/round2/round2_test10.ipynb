# %%
import Submission
# %matplotlib inline

# %%
model = Submission.Submission()
# Out:
# loading...
# 	time spend:  64.20123720169067
# training data merging...
# 	time spend:  27.806342840194702
# train shape:  (1077175, 224)
# Training LGBM model...
# [100]	valid_0's binary_logloss: 0.294503
# [200]	valid_0's binary_logloss: 0.201756
# [300]	valid_0's binary_logloss: 0.178287
# [400]	valid_0's binary_logloss: 0.172115
# [500]	valid_0's binary_logloss: 0.170185
# [600]	valid_0's binary_logloss: 0.16936
# [700]	valid_0's binary_logloss: 0.168926
# [800]	valid_0's binary_logloss: 0.168642
# [900]	valid_0's binary_logloss: 0.168442
# [1000]	valid_0's binary_logloss: 0.168307
# [1100]	valid_0's binary_logloss: 0.168206
# [1200]	valid_0's binary_logloss: 0.168125
# [1300]	valid_0's binary_logloss: 0.168063
# [1400]	valid_0's binary_logloss: 0.168017
# [1500]	valid_0's binary_logloss: 0.167969
# [1600]	valid_0's binary_logloss: 0.167923
# [1700]	valid_0's binary_logloss: 0.167888
# [1800]	valid_0's binary_logloss: 0.167852
# [1900]	valid_0's binary_logloss: 0.167818
# ...

# %%
import Submission
# %matplotlib inline

model = Submission.Submission()
# Out:
# loading...
# 	time spend:  53.254342794418335
# training data merging...
# 	time spend:  29.97587513923645
# train shape:  (1077175, 236)
# Training LGBM model...
# [100]	valid_0's binary_logloss: 0.286309
# [200]	valid_0's binary_logloss: 0.186807
# [300]	valid_0's binary_logloss: 0.157963
# [400]	valid_0's binary_logloss: 0.148532
# [500]	valid_0's binary_logloss: 0.144818
# [600]	valid_0's binary_logloss: 0.143071
# [700]	valid_0's binary_logloss: 0.142134
# [800]	valid_0's binary_logloss: 0.141547
# [900]	valid_0's binary_logloss: 0.141201
# [1000]	valid_0's binary_logloss: 0.140965
# [1100]	valid_0's binary_logloss: 0.140814
# [1200]	valid_0's binary_logloss: 0.140697
# [1300]	valid_0's binary_logloss: 0.140618
# [1400]	valid_0's binary_logloss: 0.140561
# [1500]	valid_0's binary_logloss: 0.140524
# [1600]	valid_0's binary_logloss: 0.140497
# [1700]	valid_0's binary_logloss: 0.140479
# [1800]	valid_0's binary_logloss: 0.140462
# [1900]	valid_0's binary_logloss: 0.140453
# ...
